# %% [markdown]
# # Tweet classification with naive bayes
#
# For this notebook we are going to implement a naive bayes classifier for classifying positive or negative based on the words in the tweet. Recall that for two events A and B the bayes theorem says
#
# $$ P(A|B) = \frac{P(B|A)P(A)}{P(B)} $$
#
# where P(A) and P(B) is the ***class probabilities*** and P(B|A) is called ***conditional probabilities***. this gives us the probability of A happening, given that B has occurred. So as an example if we want to find the probability of "is this a positive tweet given that it contains the word "good" " we will obtain the following
#
# $$ P(\text{"positive"}|\text{"good" in tweet}) = \frac{P("\text{"good" in tweet}|\text{"positive"})P(\text{"positive"})}{P("\text{"good" in tweet})} $$
#
# This means that to find the probability of "is this a positive tweet given that it contains the word "good" " we need the probability of "good" being in a positive tweet, the probability of a tweet being positive and the probability of "good" being in a tweet.
#
# Similarly if we want to obtain the opposite "is this a negative tweet given that it contains the word "boring" "
# we get
#
# $$ P(\text{"negative"}|\text{"boring" in tweet}) = \frac{P(\text{"boring" in tweet}|\text{"negative"})P(\text{"negative"})}{P(\text{"boring" in tweet})} $$
#
# where we need the probability of "boring" being in a negative tweet, the probability of a tweet negative being and the probability of "boring" being in a tweet.
#
# We can now build a classifier where we compare those two probabilities and whichever is the larger one it's classified as
#
# if P("positive"|"good" in tweet) $>$ P("negative"|"boring" in tweet)
#
#    Tweet is positive
#
# else
#
#    Tweet is negative
#
# Now let's expand this to handle multiple features and put the Naive assumption into bayes theroem. This means that if features are independent we have
#
# $$ P(A,B) = P(A)P(B) $$
#
# This gives us:
#
# $$ P(A|b_1,b_2,...,b_n) = \frac{P(b_1|A)P(b_2|A)...P(b_n|A)P(A)}{P(b_1)P(b_2)...P(b_n)} $$
#
# or
#
# $$ P(A|b_1,b_2,...,b_n) = \frac{\prod_i^nP(b_i|A)P(A)}{P(b_1)P(b_2)...P(b_n)} $$
#
#
# So with our previous example expanded with more words "is this a positive tweet given that it contains the word "good" and "interesting" " gives us
#
# $$ P(\text{"positive"}|\text{"good", "interesting" in tweet}) = \frac{P(\text{"good" in tweet}|\text{"positive"})P(\text{"interesting" in tweet}|\text{"positive"})P(\text{"positive"})}{P(\text{"good" in tweet})P(\text{"interesting" in tweet})} $$
#
# As you can see the denominator remains constant which means we can remove it and the final classifier end up
#
# $$y = argmax_A P(A)\prod_i^nP(b_i|A) $$

# %% [markdown]
# The dataset that you will be working with can be downloaded from the following link: https://uppsala.instructure.com/courses/66466/files

# %%
#stuff to import
import pandas as pd
import numpy as np
import random
import sklearn
from sklearn.model_selection import train_test_split

# %% [markdown]
# #### Load the data, explore and pre-processing

# %%
tweets=pd.read_csv('twitter_sentiment_analysis.csv',encoding='latin', 
                   names = ['sentiment','id','date','query','user','tweet'])
tweets
# Out:
#          sentiment          id                          date     query  \
# 0                0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1                0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2                0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3                0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4                0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 1599995          4  2193601966  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599996          4  2193601969  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599997          4  2193601991  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599998          4  2193602064  Tue Jun 16 08:40:49 PDT 2009  NO_QUERY
# 1599999          4  2193602129  Tue Jun 16 08:40:50 PDT 2009  NO_QUERY
#
#                     user                                              tweet
# 0        _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1          scotthamilton  is upset that he can't update his Facebook by ...
# 2               mattycus  @Kenichan I dived many times for the ball. Man...
# 3                ElleCTF    my whole body feels itchy and like its on fire
# 4                 Karoli  @nationwideclass no, it's not behaving at all....
# ...                  ...                                                ...
# 1599995  AmandaMarie1028  Just woke up. Having no school is the best fee...
# 1599996      TheWDBoards  TheWDB.com - Very cool to hear old Walt interv...
# 1599997           bpbabe  Are you ready for your MoJo Makeover? Ask me f...
# 1599998     tinydiamondz  Happy 38th Birthday to my boo of alll time!!! ...
# 1599999   RyanTrevMorris  happy #charitytuesday @theNSPCC @SparksCharity...
#
# [1600000 rows x 6 columns]

# %%
tweets = tweets.sample(frac=1)
tweets = tweets[:200000]
print("Dataset shape:", tweets.shape)
# Out:
# Dataset shape: (200000, 6)

# %%
tweets['sentiment'].unique()
# Out:
# array([0, 4], dtype=int64)

# %% [markdown]
# #### Currently (0 = negative and 4 = positive) changing the notation to (0 = negative and 1 = positive)

# %%
tweets['sentiment']=tweets['sentiment'].replace(4,1)
tweets
# Out:
#          sentiment          id                          date     query  \
# 160759           0  1957141723  Thu May 28 23:38:06 PDT 2009  NO_QUERY
# 76065            0  1695443868  Mon May 04 06:09:05 PDT 2009  NO_QUERY
# 47636            0  1677681440  Sat May 02 03:24:24 PDT 2009  NO_QUERY
# 1410497          1  2056295897  Sat Jun 06 10:53:09 PDT 2009  NO_QUERY
# 1414208          1  2056992525  Sat Jun 06 12:10:18 PDT 2009  NO_QUERY
# ...            ...         ...                           ...       ...
# 711678           0  2258305483  Sat Jun 20 15:42:41 PDT 2009  NO_QUERY
# 787958           0  2325024450  Thu Jun 25 04:35:50 PDT 2009  NO_QUERY
# 694763           0  2253078888  Sat Jun 20 07:32:40 PDT 2009  NO_QUERY
# 161421           0  1957301151  Fri May 29 00:05:37 PDT 2009  NO_QUERY
# 1589190          1  2191203642  Tue Jun 16 04:45:44 PDT 2009  NO_QUERY
#
#                  user                                              tweet
# 160759      nico80013                 @soonseeofpred becuz you braggin
# 76065    hunnybunch89  barely slept all night  studying some more tha...
# 47636       ariebrion       finally home buh gotta go ta werk at 8  damn
# 1410497     KitKat423  I guess someone might be too tired from partyi...
# 1414208   iRockaBerry  Grilled Chicken Torta  yummz! http://mypict.me...
# ...               ...                                                ...
# 711678      Hoolywood  Continuing my packing for das trip! I had oodl...
# 787958        PaigeXc  Had a fight with someone yesterday, and he's s...
# 694763      missclick  Way 2 go heather, over slept 2day. Should've b...
# 161421     FastKid414                    I don't ship out until October
# 1589190       im_stef  So, World History, Chemistry, English.. He I c...
#
# [200000 rows x 6 columns]

# %% [markdown]
# #### Removing the unnecessary columns.

# %%
tweets.drop(['date','query','user'], axis=1, inplace=True)
tweets.drop('id', axis=1, inplace=True)
tweets.head(10)
# Out:
#          sentiment                                              tweet
# 160759           0                 @soonseeofpred becuz you braggin
# 76065            0  barely slept all night  studying some more tha...
# 47636            0       finally home buh gotta go ta werk at 8  damn
# 1410497          1  I guess someone might be too tired from partyi...
# 1414208          1  Grilled Chicken Torta  yummz! http://mypict.me...
# 443596           0  @Lil_Wun it should just automatically be left ...
# 1504010          1            Yesterday I got one year using Blip.fm
# 440210           0                    @ThisisDavina i miss live feed
# 1011633          1       trying to figure out what goes on with this
# 1155740          1  Bought yarn to make daughters &quot;skirt&quot...

# %% [markdown]
# #### Checking if any null values present

# %%
(tweets.isnull().sum() / len(tweets))*100
# Out:
# sentiment    0.0
# tweet        0.0
# dtype: float64

# %% [markdown]
# #### Now make a new column for side by side comparison of new tweets vs old tweets

# %%
#converting pandas object to a string type
tweets['tweet'] = tweets['tweet'].astype('str')

# %% [markdown]
# #### Check the number of positive vs. negative tagged sentences

# %%
positives = tweets['sentiment'][tweets.sentiment == 1 ]
negatives = tweets['sentiment'][tweets.sentiment == 0 ]

print('Total length of the data is:         {}'.format(tweets.shape[0]))
print('No. of positve tagged sentences is:  {}'.format(len(positives)))
print('No. of negative tagged sentences is: {}'.format(len(negatives)))
# Out:
# Total length of the data is:         200000
# No. of positve tagged sentences is:  99535
# No. of negative tagged sentences is: 100465

# %%
# nltk
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
#Stop Words: A stop word is a commonly used word (such as “the”, “a”, “an”, “in”) 
#that a search engine has been programmed to ignore,
#both when indexing entries for searching and when retrieving them as the result of a search query.
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('wordnet')
stopword = set(stopwords.words('english'))
print(stopword)
# Out:
# {"should've", "aren't", 'any', 'wasn', "mightn't", 'yours', 'just', 'yourself', 'them', 'out', 'what', 'most', 'which', 'doesn', 'only', 'shouldn', 'some', 'again', 'whom', 'by', 'than', 'his', 'hers', 'be', "wouldn't", 'of', 'in', 'after', 'mightn', 'an', 'off', 'below', 'other', 'own', 'very', 'ain', 'that', 'now', 'is', 'against', 'were', 'this', 'here', "mustn't", 'itself', 'wouldn', 'until', 'do', "haven't", "you'll", 'he', 'before', 'too', 'being', 'don', 'these', "didn't", 'above', 'to', "you've", 'on', 'does', 'himself', 'if', 'mustn', 'there', 'during', 'down', "you're", 'how', 'under', 'more', 'between', 'into', "hadn't", 'have', 'me', "she's", 'for', 'at', "needn't", 'am', 'then', 'few', "it's", 'him', 'myself', 'over', 'yourselves', 'we', "shan't", 'with', "couldn't", 'why', 'ourselves', 'it', 'did', "you'd", 'hasn', 'can', 'has', 'their', "that'll", 'where', 't', 'you', 'her', 'or', 'been', 'not', 'my', 'didn', 'hadn', 'y', 'herself', 'doing', 'up', 'they', 'those', 'are', 'both', 'themselves', 'our', 'a', 'weren', 'shan', 'couldn', 'same', "weren't", 'its', 'will', 'nor', 'once', 'theirs', 'she', 'when', 'further', 'needn', "hasn't", 'about', "wasn't", 'all', 'from', 'because', 'should', 'aren', 'through', "won't", 'll', 'as', 'such', 're', "shouldn't", 'each', 'was', "doesn't", 'the', 'who', 'ours', 'won', 'had', 'no', 'your', 'and', "isn't", 've', 'o', 'd', 'ma', 'but', "don't", 'while', 'so', 'haven', 'm', 'i', 'having', 'isn', 's'}
# [nltk_data] Downloading package stopwords to C:\Users\David
# [nltk_data]     Kidane\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\David
# [nltk_data]     Kidane\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\David
# [nltk_data]     Kidane\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\David
# [nltk_data]     Kidane\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# #### Data Cleaning

# %%
import warnings
warnings.filterwarnings('ignore')
import re
import string
import pickle
urlPattern = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
userPattern = '@[^\s]+'
some = 'amp,today,tomorrow,going,girl'
def process_tweets(tweet):
  # Lower Casing
    tweet = re.sub(r"he's", "he is", tweet)
    tweet = re.sub(r"there's", "there is", tweet)
    tweet = re.sub(r"We're", "We are", tweet)
    tweet = re.sub(r"That's", "That is", tweet)
    tweet = re.sub(r"won't", "will not", tweet)
    tweet = re.sub(r"they're", "they are", tweet)
    tweet = re.sub(r"Can't", "Cannot", tweet)
    tweet = re.sub(r"wasn't", "was not", tweet)
    tweet = re.sub(r"don\x89Ûªt", "do not", tweet)
    tweet = re.sub(r"aren't", "are not", tweet)
    tweet = re.sub(r"isn't", "is not", tweet)
    tweet = re.sub(r"What's", "What is", tweet)
    tweet = re.sub(r"haven't", "have not", tweet)
    tweet = re.sub(r"hasn't", "has not", tweet)
    tweet = re.sub(r"There's", "There is", tweet)
    tweet = re.sub(r"He's", "He is", tweet)
    tweet = re.sub(r"It's", "It is", tweet)
    tweet = re.sub(r"You're", "You are", tweet)
    tweet = re.sub(r"I'M", "I am", tweet)
    tweet = re.sub(r"shouldn't", "should not", tweet)
    tweet = re.sub(r"wouldn't", "would not", tweet)
    tweet = re.sub(r"i'm", "I am", tweet)
    tweet = re.sub(r"I\x89Ûªm", "I am", tweet)
    tweet = re.sub(r"I'm", "I am", tweet)
    tweet = re.sub(r"Isn't", "is not", tweet)
    tweet = re.sub(r"Here's", "Here is", tweet)
    tweet = re.sub(r"you've", "you have", tweet)
    tweet = re.sub(r"you\x89Ûªve", "you have", tweet)
    tweet = re.sub(r"we're", "we are", tweet)
    tweet = re.sub(r"what's", "what is", tweet)
    tweet = re.sub(r"couldn't", "could not", tweet)
    tweet = re.sub(r"we've", "we have", tweet)
    tweet = re.sub(r"it\x89Ûªs", "it is", tweet)
    tweet = re.sub(r"doesn\x89Ûªt", "does not", tweet)
    tweet = re.sub(r"It\x89Ûªs", "It is", tweet)
    tweet = re.sub(r"Here\x89Ûªs", "Here is", tweet)
    tweet = re.sub(r"who's", "who is", tweet)
    tweet = re.sub(r"I\x89Ûªve", "I have", tweet)
    tweet = re.sub(r"y'all", "you all", tweet)
    tweet = re.sub(r"can\x89Ûªt", "cannot", tweet)
    tweet = re.sub(r"would've", "would have", tweet)
    tweet = re.sub(r"it'll", "it will", tweet)
    tweet = re.sub(r"we'll", "we will", tweet)
    tweet = re.sub(r"wouldn\x89Ûªt", "would not", tweet)
    tweet = re.sub(r"We've", "We have", tweet)
    tweet = re.sub(r"he'll", "he will", tweet)
    tweet = re.sub(r"Y'all", "You all", tweet)
    tweet = re.sub(r"Weren't", "Were not", tweet)
    tweet = re.sub(r"Didn't", "Did not", tweet)
    tweet = re.sub(r"they'll", "they will", tweet)
    tweet = re.sub(r"they'd", "they would", tweet)
    tweet = re.sub(r"DON'T", "DO NOT", tweet)
    tweet = re.sub(r"That\x89Ûªs", "That is", tweet)
    tweet = re.sub(r"they've", "they have", tweet)
    tweet = re.sub(r"i'd", "I would", tweet)
    tweet = re.sub(r"should've", "should have", tweet)
    tweet = re.sub(r"You\x89Ûªre", "You are", tweet)
    tweet = re.sub(r"where's", "where is", tweet)
    tweet = re.sub(r"Don\x89Ûªt", "Do not", tweet)
    tweet = re.sub(r"we'd", "we would", tweet)
    tweet = re.sub(r"i'll", "I will", tweet)
    tweet = re.sub(r"weren't", "were not", tweet)
    tweet = re.sub(r"They're", "They are", tweet)
    tweet = re.sub(r"Can\x89Ûªt", "Cannot", tweet)
    tweet = re.sub(r"you\x89Ûªll", "you will", tweet)
    tweet = re.sub(r"I\x89Ûªd", "I would", tweet)
    tweet = re.sub(r"let's", "let us", tweet)
    tweet = re.sub(r"it's", "it is", tweet)
    tweet = re.sub(r"can't", "cannot", tweet)
    tweet = re.sub(r"don't", "do not", tweet)
    tweet = re.sub(r"you're", "you are", tweet)
    tweet = re.sub(r"i've", "I have", tweet)
    tweet = re.sub(r"that's", "that is", tweet)
    tweet = re.sub(r"i'll", "I will", tweet)
    tweet = re.sub(r"doesn't", "does not", tweet)
    tweet = re.sub(r"i'd", "I would", tweet)
    tweet = re.sub(r"didn't", "did not", tweet)
    tweet = re.sub(r"ain't", "am not", tweet)
    tweet = re.sub(r"you'll", "you will", tweet)
    tweet = re.sub(r"I've", "I have", tweet)
    tweet = re.sub(r"Don't", "do not", tweet)
    tweet = re.sub(r"I'll", "I will", tweet)
    tweet = re.sub(r"I'd", "I would", tweet)
    tweet = re.sub(r"Let's", "Let us", tweet)
    tweet = re.sub(r"you'd", "You would", tweet)
    tweet = re.sub(r"It's", "It is", tweet)
    tweet = re.sub(r"Ain't", "am not", tweet)
    tweet = re.sub(r"Haven't", "Have not", tweet)
    tweet = re.sub(r"Could've", "Could have", tweet)
    tweet = re.sub(r"youve", "you have", tweet)  
    tweet = re.sub(r"donå«t", "do not", tweet)  
    
    tweet = re.sub(r"some1", "someone", tweet)
    tweet = re.sub(r"yrs", "years", tweet)
    tweet = re.sub(r"hrs", "hours", tweet)
    tweet = re.sub(r"2morow|2moro", "tomorrow", tweet)
    tweet = re.sub(r"2day", "today", tweet)
    tweet = re.sub(r"4got|4gotten", "forget", tweet)
    tweet = re.sub(r"b-day|bday", "b-day", tweet)
    tweet = re.sub(r"mother's", "mother", tweet)
    tweet = re.sub(r"mom's", "mom", tweet)
    tweet = re.sub(r"dad's", "dad", tweet)
    tweet = re.sub(r"hahah|hahaha|hahahaha", "haha", tweet)
    tweet = re.sub(r"lmao|lolz|rofl", "lol", tweet)
    tweet = re.sub(r"thanx|thnx", "thanks", tweet)
    tweet = re.sub(r"goood", "good", tweet)
    tweet = re.sub(r"some1", "someone", tweet)
    tweet = re.sub(r"some1", "someone", tweet)
    tweet = tweet.lower()
    tweet=tweet[1:]
    # Removing all URls 
    tweet = re.sub(urlPattern,'',tweet)
    # Removing all @username.
    tweet = re.sub(userPattern,'', tweet) 
    #remove some words
    tweet= re.sub(some,'',tweet)
    #Remove punctuations
    tweet = tweet.translate(str.maketrans("","",string.punctuation))
    #tokenizing words
    tokens = word_tokenize(tweet)
    #tokens = [w for w in tokens if len(w)>2]
    #Removing Stop Words
    final_tokens = [w for w in tokens if w not in stopword]
    #reducing a word to its word stem 
    wordLemm = WordNetLemmatizer()
    finalwords=[]
    for w in final_tokens:
      if len(w)>1:
        word = wordLemm.lemmatize(w)
        finalwords.append(word)
    return ' '.join(finalwords)

# %%
abbreviations = {
    "$" : " dollar ",
    "€" : " euro ",
    "4ao" : "for adults only",
    "a.m" : "before midday",
    "a3" : "anytime anywhere anyplace",
    "aamof" : "as a matter of fact",
    "acct" : "account",
    "adih" : "another day in hell",
    "afaic" : "as far as i am concerned",
    "afaict" : "as far as i can tell",
    "afaik" : "as far as i know",
    "afair" : "as far as i remember",
    "afk" : "away from keyboard",
    "app" : "application",
    "approx" : "approximately",
    "apps" : "applications",
    "asap" : "as soon as possible",
    "asl" : "age, sex, location",
    "atk" : "at the keyboard",
    "ave." : "avenue",
    "aymm" : "are you my mother",
    "ayor" : "at your own risk", 
    "b&b" : "bed and breakfast",
    "b+b" : "bed and breakfast",
    "b.c" : "before christ",
    "b2b" : "business to business",
    "b2c" : "business to customer",
    "b4" : "before",
    "b4n" : "bye for now",
    "b@u" : "back at you",
    "bae" : "before anyone else",
    "bak" : "back at keyboard",
    "bbbg" : "bye bye be good",
    "bbc" : "british broadcasting corporation",
    "bbias" : "be back in a second",
    "bbl" : "be back later",
    "bbs" : "be back soon",
    "be4" : "before",
    "bfn" : "bye for now",
    "blvd" : "boulevard",
    "bout" : "about",
    "brb" : "be right back",
    "bros" : "brothers",
    "brt" : "be right there",
    "bsaaw" : "big smile and a wink",
    "btw" : "by the way",
    "bwl" : "bursting with laughter",
    "c/o" : "care of",
    "cet" : "central european time",
    "cf" : "compare",
    "cia" : "central intelligence agency",
    "csl" : "can not stop laughing",
    "cu" : "see you",
    "cul8r" : "see you later",
    "cv" : "curriculum vitae",
    "cwot" : "complete waste of time",
    "cya" : "see you",
    "cyt" : "see you tomorrow",
    "dae" : "does anyone else",
    "dbmib" : "do not bother me i am busy",
    "diy" : "do it yourself",
    "dm" : "direct message",
    "dwh" : "during work hours",
    "e123" : "easy as one two three",
    "eet" : "eastern european time",
    "eg" : "example",
    "embm" : "early morning business meeting",
    "encl" : "enclosed",
    "encl." : "enclosed",
    "etc" : "and so on",
    "faq" : "frequently asked questions",
    "fawc" : "for anyone who cares",
    "fb" : "facebook",
    "fc" : "fingers crossed",
    "fig" : "figure",
    "fimh" : "forever in my heart", 
    "ft." : "feet",
    "ft" : "featuring",
    "ftl" : "for the loss",
    "ftw" : "for the win",
    "fwiw" : "for what it is worth",
    "fyi" : "for your information",
    "g9" : "genius",
    "gahoy" : "get a hold of yourself",
    "gal" : "get a life",
    "gcse" : "general certificate of secondary education",
    "gfn" : "gone for now",
    "gg" : "good game",
    "gl" : "good luck",
    "glhf" : "good luck have fun",
    "gmt" : "greenwich mean time",
    "gmta" : "great minds think alike",
    "gn" : "good night",
    "g.o.a.t" : "greatest of all time",
    "goat" : "greatest of all time",
    "goi" : "get over it",
    "gps" : "global positioning system",
    "gr8" : "great",
    "gratz" : "congratulations",
    "gyal" : "girl",
    "h&c" : "hot and cold",
    "hp" : "horsepower",
    "hr" : "hour",
    "hrh" : "his royal highness",
    "ht" : "height",
    "ibrb" : "i will be right back",
    "ic" : "i see",
    "icq" : "i seek you",
    "icymi" : "in case you missed it",
    "idc" : "i do not care",
    "idgadf" : "i do not give a damn fuck",
    "idgaf" : "i do not give a fuck",
    "idk" : "i do not know",
    "ie" : "that is",
    "i.e" : "that is",
    "ifyp" : "i feel your pain",
    "IG" : "instagram",
    "iirc" : "if i remember correctly",
    "ilu" : "i love you",
    "ily" : "i love you",
    "imho" : "in my humble opinion",
    "imo" : "in my opinion",
    "imu" : "i miss you",
    "iow" : "in other words",
    "irl" : "in real life",
    "j4f" : "just for fun",
    "jic" : "just in case",
    "jk" : "just kidding",
    "jsyk" : "just so you know",
    "l8r" : "later",
    "lb" : "pound",
    "lbs" : "pounds",
    "ldr" : "long distance relationship",
    "lmao" : "laugh my ass off",
    "lmfao" : "laugh my fucking ass off",
    "lol" : "laughing out loud",
    "ltd" : "limited",
    "ltns" : "long time no see",
    "m8" : "mate",
    "mf" : "motherfucker",
    "mfs" : "motherfuckers",
    "mfw" : "my face when",
    "mofo" : "motherfucker",
    "mph" : "miles per hour",
    "mr" : "mister",
    "mrw" : "my reaction when",
    "ms" : "miss",
    "mte" : "my thoughts exactly",
    "nagi" : "not a good idea",
    "nbc" : "national broadcasting company",
    "nbd" : "not big deal",
    "nfs" : "not for sale",
    "ngl" : "not going to lie",
    "nhs" : "national health service",
    "nrn" : "no reply necessary",
    "nsfl" : "not safe for life",
    "nsfw" : "not safe for work",
    "nth" : "nice to have",
    "nvr" : "never",
    "nyc" : "new york city",
    "oc" : "original content",
    "og" : "original",
    "ohp" : "overhead projector",
    "oic" : "oh i see",
    "omdb" : "over my dead body",
    "omg" : "oh my god",
    "omw" : "on my way",
    "p.a" : "per annum",
    "p.m" : "after midday",
    "pm" : "prime minister",
    "poc" : "people of color",
    "pov" : "point of view",
    "pp" : "pages",
    "ppl" : "people",
    "prw" : "parents are watching",
    "ps" : "postscript",
    "pt" : "point",
    "ptb" : "please text back",
    "pto" : "please turn over",
    "qpsa" : "what happens", 
    "ratchet" : "rude",
    "rbtl" : "read between the lines",
    "rlrt" : "real life retweet", 
    "rofl" : "rolling on the floor laughing",
    "roflol" : "rolling on the floor laughing out loud",
    "rotflmao" : "rolling on the floor laughing my ass off",
    "rt" : "retweet",
    "ruok" : "are you ok",
    "sfw" : "safe for work",
     "sk8" : "skate",
    "smh" : "shake my head",
    "sq" : "square",
    "srsly" : "seriously", 
    "ssdd" : "same stuff different day",
    "tbh" : "to be honest",
    "tbs" : "tablespooful",
    "tbsp" : "tablespooful",
    "tfw" : "that feeling when",
    "thks" : "thank you",
    "tho" : "though",
    "thx" : "thank you",
    "tia" : "thanks in advance",
    "til" : "today i learned",
    "tl;dr" : "too long i did not read",
    "tldr" : "too long i did not read",
    "tmb" : "tweet me back",
    "tntl" : "trying not to laugh",
    "ttyl" : "talk to you later",
    "u" : "you",
    "u2" : "you too",
    "u4e" : "yours for ever",
    "utc" : "coordinated universal time",
    "w/" : "with",
    "w/o" : "without",
    "w8" : "wait",
    "wassup" : "what is up",
    "wb" : "welcome back",
    "wtf" : "what the fuck",
    "wtg" : "way to go",
    "wtpa" : "where the party at",
    "wuf" : "where are you from",
    "wuzup" : "what is up",
    "wywh" : "wish you were here",
    "yd" : "yard",
    "ygtr" : "you got that right",
    "ynk" : "you never know",
    "zzz" : "sleeping bored and tired"
}

# %%
def convert_abbrev_in_text(tweet):
    t=[]
    words=tweet.split()
    t = [abbreviations[w.lower()] if w.lower() in abbreviations.keys() else w for w in words]
    return ' '.join(t)

# %% [markdown]
# #### Text processing completed

# %%
tweets['processed_tweets'] = tweets['tweet'].apply(lambda x: process_tweets(x))
tweets['processed_tweets'] = tweets['processed_tweets'].apply(lambda x: convert_abbrev_in_text(x))
print('Text Preprocessing complete.')
tweets

# %%
#removing shortwords
tweets['processed_tweets']=tweets['processed_tweets'].apply(lambda x: " ".join([w for w in x.split() if len(w)>3]))
tweets.head(5)
# Out:
#          sentiment                                              tweet  \
# 1572347          1  @Jaypee_McSteamy i love GSP  he's so damn fine...
# 83648            0  I can't twit pic in the &quot;ladies bar&quot;...
# 860819           1    @johnmaine i can't wait for warped tour either
# 498235           0  My craving is not satisfied  this is day 3 of ...
# 303278           0  starts back to school tomorrow.  Just left Vin...
#
#                                           processed_tweets
# 1572347                 jaypeemcsteamy love damn fineeeeee
# 83648                  twit quotladies barquot sorry tweet
# 860819                   johnmaine wait warped tour either
# 498235                                   craving satisfied
# 303278   tart back school tomorrow left vince loras las...

# %% [markdown]
# Now lets split the data into a training set and a test set using scikit-learns train_test_split function
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html

# %%
tweets_data = tweets["processed_tweets"]
tweets_labels = tweets["sentiment"]

train_tweets, test_tweets, train_labels, test_labels = train_test_split(tweets_data, tweets_labels, test_size=0.2)
#Split data into train_tweets, test_tweets, train_labels and test_labels

# %% [markdown]
# What we need to build our classifier is "probability of positive tweet" P(pos) , "probability of negative tweet" P(neg), "probability of word in tweet given tweet is positive" P(w|pos) and "probability of word in tweet given tweet is negative" P(w|neg). Start by calculating the probability that a tweet is positive and negative respectively

# %%
sum_of_pos = (tweets_labels == "pos").sum()
sum_of_neg = (tweets_labels == "neg").sum()

P_pos = sum_of_pos / len(tweets_labels)
P_neg = sum_of_neg / len(tweets_labels)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_libs\index.pyx:146, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\index_class_helper.pxi:49, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'pos'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [279], line 1
# ----> 1 sum_of_pos = tweets_labels.value_counts()["pos"]
#       2 sum_of_neg = tweets_labels.value_counts()["neg"]
#       5 P_pos = sum_of_pos / len(tweets_labels)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
#     983 if is_hashable(key):
#     984     # Otherwise index.get_value will raise InvalidIndexError
#     985     try:
#     986         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\series.py:1089, in Series._get_value(self, label, takeable)
#    1086     return self._values[label]
#    1088 # Similar to Index.get_value, but we do not fall back to positional
# -> 1089 loc = self.index.get_loc(label)
#    1090 return self.index._get_values_for_loc(self, loc, label)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'pos'

# %% [markdown]
# For P(w|pos), P(w|neg) we need to count how many tweets each word occur in. Count the number of tweets each word occurs in and store in the word counter. An entry in the word counter is for instance {'good': 'Pos':150, 'Neg': 10} meaning good occurs in 150 positive tweets and 10 negative tweets. Be aware that we are not interested in calculating multiple occurances of the same word in the same tweet. Also we change the labels from 0 for "Negative" and 1 for "Positive" to "Neg" and "Pos" respectively.For each word convert it to lower case. You can use Python's [lower](https://www.w3schools.com/python/ref_string_lower.asp). Another handy Python string method is [split](https://www.w3schools.com/python/ref_string_split.asp).

# %%
new_train_labels = train_labels.replace(0, "Neg", regex=True)
final_train_labels = new_train_labels.replace({"pos": "Pos", "neg": "Neg"})
word_counter = {}

for tweet, label in zip(train_tweets, final_train_labels):
    words = (tweet.lower()).split()
    
    for word in set(words):
        if word not in word_counter:
            word_counter[word] = {'Pos': 0, 'Neg': 0}
        if label == "Pos":
            word_counter[word]["Pos"] += 1
        elif label == "Neg":
            word_counter[word]["Neg"] += 1
    print(words)
# ... Count number of tweets each word occurs in and store in word_counter where an entry looks like ex. {'word': 'Pos':98, 'Neg':10}
# Out:
# ['atchin', 'fanboys', 'homies', 'internet', 'till', 'monday']
# ['inally', 'talked', 'state', 'farm', 'getting', 'ready', 'clean', 'today', 'tomorrow', 'chainsaw', 'monday']
# ['momhoodmoments', 'awwwwell', 'want', 'meet', 'mine', 'play', 'game']
# ['3xasif', 'laughing', 'loud', 'ever', 'forget']
# ['like', 'ignore', 'text', 'message', 'twitter', 'know', 'whoretear', 'drop']
# ['berk', 'best']
# ['ambo', 'getting', 'saturday', 'afternoon', 'blow', 'nothing', 'better', 'good', 'blowdry']
# ['ningningning', '2990', 'drink', 'passport', 'used', 'friend', 'drink', 'left', 'haha']
# ['adookie', 'crack', 'quicker']
# ['ebassman', 'night', 'guest', 'star', 'true', 'blood', 'next', 'season']
# ['cream', 'back', 'dont', 'feel', 'good']
# ['vacation', 'thing', 'looking', 'better', 'already']
# ['farkette', 'happy', 'birthday', 'still', 'feel', 'much', 'time', 'well']
# ['work', 'super', 'bored']
# ['forgot', 'pretty', 'baltimore']
# ['hurt', 'standing', 'walking', 'thatt', 'time', 'really', 'wana', 'joke']
# ['iamjersey', 'cant', 'love', 'andy']
# ['watch', 'church', 'live', 'make', 'service', 'person', 'next', 'best', 'thing']
# ['donrushnapoleon', 'baby', 'asleep', 'store', 'wats', 'circle', 'next', 'door']
# ['thecolonial', 'hand', 'really', 'viemu', 'input', 'system', 'hack', 'needed']
# ['glad', 'everyone', 'enjoyed', 'waiting', 'write', 'chapter']
# ['take', 'ontario', 'mill']
# ['cant', 'believe', 'goin', 'miss', 'dance', 'show']
# ['woke', 'feeling', 'like', 'rubbish']
# ['breakfast', 'thing', 'called', 'work']
# ['jumonsmapes', 'send', 'send']
# ['raining', 'singapore', 'sleeping', 'double', 'pleasure', 'great', 'time']
# ['back', 'laying', 'hotel', 'soooooo', 'excited', 'many', 'thing', 'havent', 'heard', 'sweetface']
# ['much', 'stuff', 'dowanna', 'beach', 'though']
# ['mlenty', 'thanks', 'honey', 'cute']
# ['break', 'continue']
# ['¡ðµð¹ñ\x87ð°ñ', 'ñ\x83ñ\x88ð°ñ\x8e', 'abba', 'thewinner', 'take']
# ['durando', 'trending', 'topic']
# ['kelcouch', 'think', 'fanvid', 'using', 'song']
# ['jonasbrothers', 'storm', 'turn', 'right']
# ['wait', 'till', 'back', 'tell', 'opinion', 'crazy', 'tweet']
# ['blasael', 'thanks', 'birthday', 'wish', 'much', 'appreciated', 'xoxoxo']
# ['swear', 'mcfly', 'unplugged', 'show', 'would', 'nice']
# ['appiness', 'point', 'childlike', 'dream', 'coincide', 'adult', 'expectation', 'sounded', 'good', 'said']
# ['jameswoon', 'jealousness', 'grrrr', 'prettyfy', 'mine', 'tommorowwww', 'steal', 'word']
# ['tommyatherton', 'suck', 'hopefully', 'trick', 'finger', 'crossed']
# ['wittering', 'sandra', 'waving', 'getting']
# ['2boknows', 'heelsandhightops', 'baybee', 'whoop', 'whoop', 'laughing', 'loud', 'preciate']
# ['frankiethesats', 'wanted', 'ticket', 'sold', 'wish', 'could', 'ahve', 'comee']
# ['spent', 'minute', 'book', 'store', 'bought', 'book']
# ['missjademusic', 'sweetie', 'suppose', 'video', 'shoot']
# ['missing', 'baby']
# ['mileycyrus', 'ache', 'tooo', 'turned', 'infection', 'suck']
# ['brittneytee', 'waiter', 'look', 'like', 'steve']
# ['lazalonso', 'spank', 'nigroy', 'aint', 'following']
# ['hopping', 'jordy']
# ['cupcake', 'gone', 'reflux', 'kickin', 'could', 'sprinkle', 'laptop', 'next', 'time', 'tweet']
# ['drinking', 'packing', 'last', 'night', 'rest', 'hangover', 'serf', 'right1']
# ['going', 'star', 'diet', 'routine', 'tomorrow']
# ['xandarr2112', 'weird', 'hope', 'figure', 'happens', 'fixed']
# ['tramell', 'today', 'laughing', 'loud', 'reading', 'before', 'sleep']
# ['gluestickgirl', 'thank', 'happy']
# ['finished', 'wildflower', 'triathalon', 'hour', 'minute', 'mile', 'swim', 'mile', 'bike', 'mile']
# ['comfortable', 'suck', 'mainofabolous', 'south', 'weezy', 'soon']
# ['simonthesnowman', 'ride', 'home', 'alone', 'black']
# ['jessicacurtis', 'want', 'know', 'follow', 'friday', 'read']
# ['downtothewire', 'eyyy']
# ['sarahanddrew', 'take', 'real', 'wear', 'pink']
# ['asexiness']
# ['mileless', 'description', 'really', 'accuratefreaky']
# ['cincodenada', 'diskpie', 'show', 'drive', 'chart', 'slice', 'directory', 'bigger', 'slicemore', 'data', 'free', 'though']
# ['selenagomez', 'girlat', 'first', 'followed', 'wrong', 'following', 'youuthe', 'real', 'awesomeyou', 'idoli', 'love', 'youu', 'much']
# ['twitter', 'profile', 'worth']
# ['like', 'sick']
# ['talinda', 'love', 'show', 'instant', 'addiction']
# ['rain', 'enough', 'suck', 'life', 'first', 'game', 'ticket', 'well', 'johan', 'start']
# ['shedletsky', 'killing', 'trade', 'currency', 'many', 'loot', 'outburst', 'control', 'control']
# ['orking', 'sunday']
# ['amily', 'relative', 'perth', 'seem', 'keen', 'visiting', 'visiting', 'melbourne', 'swine', 'capital', 'australia']
# ['issing', 'already']
# ['kcornwall', 'pool', 'steam', 'room', 'nice', 'perk']
# ['gave', 'history', 'presentation', 'middle', 'passage', 'internally', 'shaking']
# ['tired', 'nervous', 'want']
# ['eading', 'heddon', 'twitter', 'face', 'face', 'change']
# ['went', 'full', 'house', 'jack', 'queen', 'lost', 'quad']
# ['brought', 'melody', 'work', 'wish', 'could', 'baby', 'bjorn']
# ['trapeze', 'wonderful', 'never', 'meant', 'last', 'snuggled', 'breakoffs', 'blow', 'still', 'love', 'love']
# ['claudiamcfly', 'hahaahahhahaaaaa', 'need', 'mind']
# ['kittiewong', 'worse', 'like', 'darth', 'vader', 'windpipe', 'inflated', 'whatnot', 'yoga', 'helped']
# ['blogging', 'buddy', 'blast', 'though', 'love', 'little', 'itty', 'bitty', 'piece', 'saving', 'broke', 'stack']
# ['iccups', 'suck']
# ['itty', 'head', 'coldy', 'kitty', 'sads']
# ['aking', 'early']
# ['danmikhael', 'hoser', 'definitely', 'human', 'sneaky', 'suspicion', 'quotegoquot', 'issuesposted', 'link', 'chill', 'geek']
# ['katrus', 'stan']
# ['need', 'make', 'homework', 'want', 'make', 'need', 'back', 'full', 'stomach', 'homework', 'ready']
# ['text', 'later', 'breathe']
# ['cute', 'gypsy', 'earring', 'bothering', 'take']
# ['aaahhh', 'running', 'rythm']
# ['johnsens', 'yeah', 'laughing', 'loud', 'still', 'want', 'follower', 'though']
# ['maybemybaby', 'hello', 'hope', 'well']
# ['hinks', 'lunchtime', 'back', 'work']
# ['sleep', 'tired', 'insomniac', 'drive', 'anywhere']
# ['raymondpirouz', 'management', 'expensive', 'hope', 'afford']
# ['julieselboe', 'much']
# ['rying', 'adult', 'difficult', 'find']
# ['comcastbill', 'make', 'deadline', 'gain', 'access', 'ecobilldue', 'internet', 'failing']
# ['hate', 'friend', 'show']
# ['rick', 'rolld', 'possible', 'laughing', 'loud']
# ['frandorsela', 'awww', 'goodbye', 'gorgeous', 'ummmmm', 'nottttt', 'haha']
# ['ttpbitlypskj6', 'letoya', 'luckett', 'lance', 'gross', 'sexy', 'self']
# ['walk', 'cream', 'love']
# ['lost', 'package', 'sisterly', 'love', 'facebook']
# ['twit', 'make', 'great']
# ['disneysociety', 'thank', 'cant', 'wait', 'today', 'learned', 'first', 'episode']
# ['sylverman', 'know', 'directing', 'comment']
# ['asmina', 'happy']
# ['lease', 'forgive', 'brother', 'paying', 'cable', 'bill', 'please', 'watch', 'cavs', 'game', 'someone', 'crib', 'wingstop']
# ['ableton', 'suite', 'finaliy', 'installed']
# ['louisaloon', 'louisa', 'guess', 'facebook', 'school']
# ['spartacus007', 'working', 'something', 'summer', 'another', 'soap', 'project', 'keep', 'finger', 'crossed']
# ['organizersandy', 'taking', 'compliment']
# ['hattin', 'shamar']
# ['matthewpetro', 'want', 'mannag', 'expert', 'talk', 'obsessive', 'seriously']
# ['joshthomas87', 'perosn', 'excited', 'looll']
# ['hhhh', 'another', 'work', 'atleast', 'tired']
# ['parker008', 'blipped', 'stuff', 'fact', 'yelly', 'gettin', 'samba', 'better']
# ['phoned', 'boyfriend', 'play', 'telephone', 'outro', 'britneys', 'knockin', 'door', 'hung']
# ['done', 'reading', 'book', 'morganville', 'vampire', 'serieswhich', 'awesome', 'idea', 'readdont', 'twilight']
# ['evilth1rt3en', 'thanks']
# ['body', 'hurt', 'worth']
# ['felt', 'sick', 'tired', 'yesterday', 'fresh', 'recruit', 'improper', 'cheer', 'babygirl', 'dahyeong']
# ['nealalex', 'assume', 'richard', 'arrived']
# ['starsandwings', 'heidi', 'looked', 'amazing', 'cuteand', 'happy', 'kristin', 'wanted', 'steph', 'maid', 'honor', 'though']
# ['back', 'life', 'farm', 'felt', 'like', 'city', 'girl', 'comp', 'like', 'wathced', 'movie', 'night', 'long']
# ['seen', 'donnie', 'darko', 'favourite', 'movie', 'time', 'noundiessunday']
# ['tommcfly', 'huuuge', 'rockstar', 'play', 'instrument', 'replyy', 'please', 'tommy']
# ['ishing', 'scintillating', 'sunday', 'feel', 'life', 'throughout']
# ['jeankai']
# ['hould', '20376889', 'tweet', 'removing', 'celeb', 'follow', 'list', 'riciculous', 'much', 'someone', 'tweet', 'thought']
# ['impalaguy', 'today', 'wasnâ´t', 'really', 'buuut', 'itâ´s', 'really', 'make']
# ['hope', 'busy', 'today', 'want', 'also', 'hope', 'jessica', 'super', 'late']
# ['tornado', 'clothes', 'room']
# ['heathenshearth', 'voted']
# ['saidin', 'saidar', 'light', 'dark']
# ['sometime', 'night', 'drag', 'scratching', 'door', 'tummy', 'scratched']
# ['made', 'chocolate', 'souffle', 'however', 'didnt', 'really', 'rise', 'occation', 'tasted', 'awesome', 'mmmm']
# ['teufl0302', 'thank']
# ['lready', 'looking', 'forward', 'chelsea', 'chelsea', 'bang', 'bang', 'wait', 'next', 'march']
# ['eally', 'fucking', 'pist', 'cant', 'wait', 'move', 'away', 'everyone']
# ['alrd', 'asleep', 'without', 'giving', 'gdnite', 'wish', 'kiss', 'feel', 'like', 'toking']
# ['werdnum', 'quotcry', 'river', 'build', 'bridge', 'itquot']
# ['roblem', 'laptop', 'wireless', 'fixed']
# ['samjmoody', 'happy', 'mother']
# ['charlie', 'horse', 'back', 'back', 'sleep', 'much', 'pain', 'right']
# []
# ['tiffemiller', 'cant', 'wait', 'thank', 'text', 'mean']
# ['mymelange', 'come', 'mind']
# ['ooooo', 'party', 'timeeeee']
# ['lunch', 'tony', 'kevin', 'check']
# ['happy', 'going', 'shopping']
# ['realized', 'error', 'actually', 'hyperventilating', 'thought', 'travel']
# ['izards', 'waverly', 'place', 'awesome', 'last', 'night', 'hope', 'everyone', 'great', 'sunday', 'great', 'week']
# ['official', 'given', 'ajax']
# ['feel', 'like', 'laying', 'refinnyj', 'ltgt', 'mat1234']
# ['pdxlilly', 'like', 'haircut', 'unfortunately', 'think', 'right', 'kind', 'hair']
# ['adly', 'week', 'chocolate', 'favorite', 'lululemon', 'jacket', 'least', 'wash', 'chocolate', 'good', 'though']
# ['bouska', 'want', 'noh8', 'photo', 'jealous']
# ['chefromthebay', 'drunk', 'twitts', 'school', 'tomorrow', 'goin', 'home', 'fighting']
# ['mattmatt44mm', 'used', 'many', 'follow', 'friday', 'twittersad']
# ['tweetdeck', 'longer', 'minimise', 'inconny', 'thing', 'vista', 'keep', 'window', 'open', 'unwieldy']
# ['ended', 'dead', 'beat', 'father', 'thanks', 'lady', 'name', 'crack', 'cocaine', 'mother', 'father']
# ['morning', 'dreich', 'monday', 'morning']
# ['spiderogumi', 'london', 'give', 'visit', 'look', 'might', 'backstage']
# ['haveyouever', 'spent', 'hundred', 'christmas', 'gift', 'someone', 'suppose', 'gift', 'well', 'recieve', 'anything', 'shake', 'head', 'laughing', 'loud']
# ['ctham', 'read', 'mandarin']
# ['jordanknight', 'soooo', 'didnt', 'know', 'passport', 'gutted', 'instead']
# ['joshlevscnn', 'helicopter', 'iran', 'dropping', 'real', 'acid', 'causing', 'people', 'burn', 'badly']
# ['think', 'ever', 'missed', 'playing', 'sport', 'right', 'seriously', 'torture']
# ['tonyg2388', 'without', 'blackberry']
# ['mother', 'cold', 'hope', 'ahaha', 'watching', 'jerry', 'springer', 'jerry', 'jerry', 'jerry']
# ['lizzieiscool', 'work']
# ['roundtrip', 'forgot', 'give', 'attribution', 'follow', 'recommendation', 'personally', 'digest', 'post']
# ['charlotte44', 'beating', 'white', 'doughy', 'cheescake', 'fridge', 'laughing', 'loud']
# ['praxxis', 'though', 'stick', 'pcxbox360', 'gaming', 'make']
# ['iendoo', 'think', 'dance', 'bollywood']
# ['oooood', 'night', 'going', 'sleep', 'lovely', 'mood']
# ['kourtneydenise', 'whoop', 'cant', 'spell', 'today', '2004', '2006']
# ['currykidd', 'funny', 'creation', 'joss', 'whedon', 'buffy', 'angel', 'firefly', 'hard', 'explain', 'good']
# ['ungrywhere', 'everyone']
# ['mariluxoxo', 'bummer', 'thank', 'anyway', 'amiga']
# ['well', 'work', 'accent', 'pretend']
# ['shontellelayne', 'hello', 'shontelle', 'love', 'song', 'especially', 'tshirt', 'stuck']
# ['icingstores']
# ['ttptwitpiccom672se', 'chillin', 'sister', 'crib']
# ['atching', 'little', 'brother', 'make', 'soap', 'sculpture', 'catching']
# ['dermatois', 'making', 'wait', 'month', 'what', 'fuck', 'armpit', 'skin', 'burning', 'hope', 'serious', 'owww']
# ['icontips', 'xoxo']
# ['candy156sweet', 'thanks']
# ['selenagomez', 'think', 'seeing', 'tonight', 'excited']
# ['paper', 'write', 'night']
# ['eeling', 'rubbish', 'today']
# ['redheadwriting', 'funny', 'reminded', 'need', 'today']
# ['appy', 'saturday', 'tweetsoh', 'goodness', 'battered', 'rain', 'today', 'sluggish', 'dayoh', 'look', 'finally']
# ['sebastianj', 'awesome', 'bunch', 'definitely', 'worth', 'visit']
# ['atching', 'king', 'missed', 'first', 'four', 'minute']
# ['hoto', 'scott', 'boyfriend']
# ['ummed', 'computer', 'crashedwondering', 'replace', 'everything']
# ['parent', 'sold']
# ['ragingbitch', 'mental', 'still', 'loyal']
# ['allisonnazarian', 'quickly', 'friend', 'yesterday', 'daughter', 'today', 'nearing', 'flash', 'grown']
# ['megamiashe', 'smell', 'terrible', 'automatically', 'better', 'charlies', 'room', 'biohazard', 'swear']
# ['veryone', 'havin', 'holiday', 'weekend', 'except']
# ['redfella', 'laughing', 'loud', 'would', 'funny', 'choc', 'people', 'gold']
# ['done', 'swimmingg']
# ['orking', 'sunday', 'getting', 'stuff', 'done', 'enough']
# ['jackieekong', 'hiya', 'whats', 'parent', 'gotten', 'bike']
# ['tired', 'sleep']
# ['thats', 'make', 'hard', 'dinner']
# ['chicken', 'nugget', 'chinese', 'place', 'mall', 'yummeh']
# ['bfiller', 'really', 'nice', 'best', 'part', 'waiting', 'line', 'checkin']
# ['oing', 'school', 'remediation']
# ['awake', 'earlier', 'daynice']
# ['ellaeske', 'cool', 'bean', 'wack', 'rapidshare', 'send', 'link']
# ['wesome', 'night']
# ['truggling', 'used', 'think', 'life', 'really', 'simple', 'looked', 'desk', 'thank', 'life', 'messy']
# ['appy', 'coming', 'home', 'utah']
# ['hillin', 'pappado', 'crew', 'missed', 'dawgs']
# ['taken', 'school', 'henderson']
# ['donniewahlberg', 'house', 'call', 'need', 'back', 'montreal', 'baby']
# ['chiinarr', 'laughing', 'loud', 'marry', 'american', 'green', 'card', 'audition', 'filed', 'dutch', 'nationality', 'like', 'year']
# ['itting', 'work']
# ['hair', 'mess', 'stomach', 'feeling', 'good']
# ['pinkfroggg', 'boyfriend', 'much', 'longer', 'keep', 'making', 'jump', 'foot', 'like']
# ['weather', 'perfect', 'lying', 'ordering', 'chinese', 'food']
# ['songwritertc', 'laughing', 'loud', 'wish', 'bite']
# ['sshap', 'place', 'coming', 'together', 'nicely', 'thanks', 'neighbor', 'friendly', 'pool', 'downstairs', 'could']
# ['brentgudgel', 'tell', 'said', 'thati', 'sure', 'agree']
# ['neosurgehosting', 'yeah', 'unfortunately', 'lower', 'level', 'access', 'rsync', 'would', 'much', 'faster']
# ['mrscantz', 'bachelorette', 'party', 'friend', 'took', 'college', 'knew', 'innocent']
# ['uhhuhhermusic', 'wowu', 'like', 'englandyou', 'update', 'agesampthen', 'come', 'laughing', 'loud', 'welcome', 'back']
# ['elyssa', 'kathryn', 'ziemba', 'right', 'love', 'death', '6609']
# ['well']
# ['daver', 'even', 'save', 'buck', 'admission', 'book', 'flight']
# ['uess', 'year', 'wench']
# ['kspidel', 'damnit', 'foiled']
# ['woken', 'slept', 'hour', 'month', 'feel', 'good', 'great', 'escape', 'comedown', 'though']
# ['helby', 'actually', 'look', 'like', 'shes', 'graduating', 'junior', 'high', 'thanks']
# ['rying', 'puppy']
# ['pradyotghate', 'many', 'destroyed', 'wall', 'dying', 'shot']
# ['galiano', 'coat', 'wait', 'winter', 'fantastico', 'shop', 'osaka']
# ['oday', 'feel', 'good', 'actually', 'feel', 'like', 'million', 'dollar', 'look', 'like', 'trillion', 'xoxo', 'baby', 'fever', 'though', 'feel', 'better']
# ['uchiesss']
# ['mackenziesmomma', 'good', 'night', 'sorry', 'friend', 'ditched']
# ['omorrow', 'finally', 'tackle', 'facebook', 'email', 'sent', 'facebook', 'responded', 'sorry']
# ['charltonbrooker', 'well', 'said', 'word', 'nick', 'griffin', 'seat']
# ['mmmi', 'cant', 'breath']
# ['mattandkim', 'wait', 'though', 'rain', 'persist', 'follow']
# ['rosemaryconley', 'done', 'killed', 'phew', 'show', 'unfit', 'glad', 'live', 'high', 'rise', 'flat', 'floor']
# ['riffin', 'technology', 'fail', 'signature', 'required', 'delivery', 'iphone', 'case', 'till', 'monday', 'best']
# ['cjsensei', 'welcome']
# ['akavirtualpa', 'stayed', 'social', 'till', 'closed', 'vodka', 'bull', 'night', 'good', 'idea']
# ['ticklemejoey', 'awesome', 'colombia', 'love', 'laura', 'love', 'joseph']
# ['redii', 'mean', '30quot', 'generally', 'totally', 'year', 'unfortunately', 'move', 'tinier', 'workplace']
# ['going', 'watch', 'bang', 'theory', 'believe', 'like', 'watch']
# ['walmart', 'getting', 'mother', 'card', 'every', 'procrastinating', 'chattanooga', 'slim', 'picking', 'good']
# ['calif', 'drinking', 'wine', 'dinner', 'friend', 'tonight', 'raining', 'much']
# ['oading', 'watching', 'nothing', 'truth']
# ['sorrrrry', 'spilling', 'wine', 'boob', 'drink']
# ['phone', 'amazing', 'boyfriend', 'hehe', 'life']
# ['mileycyrus', 'love', 'song']
# ['amyshell', 'awww', 'took', 'numba', 'forgot', 'return', 'methinks']
# ['ahaa', 'class', 'start', 'noww']
# ['month', 'since', 'david', 'left', 'philippine', 'hahaa']
# ['oing', 'back', 'posting', 'directly', 'facebookjust', 'follow', 'others']
# ['backdropcities', 'never', 'write', 'facebook']
# ['signed', 'indie', 'game', 'service', 'soft', 'launch', 'monday', 'launch', 'july', 'exciting']
# ['earing', 'bliss', 'muse', 'every', 'song', 'muse', 'epic']
# ['chesterbe', 'make']
# ['rugby', 'leinster', 'rockys', 'left', 'coming', 'back', 'signed', 'deal', 'brumbies', 'great', 'season']
# ['calder', 'center', 'doin', 'project', 'apartment', 'want', 'join']
# ['twebbstack', 'know', 'haha', 'night']
# ['verything', 'keep', 'crashing', 'well', 'thems', 'break']
# ['ghup', 'hate', 'west', 'east', 'coast', 'flight', 'leave', 'arrive', 'birmingham']
# ['mileycyrus', 'miley', 'thats', 'funny', 'movie', 'favs', 'haha', 'great']
# ['world', 'fuckt']
# ['miss']
# ['laryngitis']
# ['nyone', 'mobypic', 'gprs', 'trouble', 'available', 'quick', 'test', 'next', 'minute', 'mobilewaysde']
# ['jbfutureboy', 'adore']
# ['krypticminds', 'always', 'smart', 'somewhere']
# ['pembsdave', 'dull', 'answer', 'laughing', 'loud', 'coward']
# ['mused', 'grandma', 'know', 'laker', 'player', 'like', 'gasol', 'odom', 'ariza', 'fisher']
# ['husband', 'care']
# ['ongg', 'sooo', 'wish', 'birthday', 'bash', 'right', 'watcin', 'gucci', 'kill', 'well', 'always', 'next']
# ['glasgowlassy', 'stroking', 'pussy', 'topic', 'never', 'bath', 'laughing', 'loud']
# ['spent', 'long', 'today', 'headache', 'also', 'hate', 'thing', 'bought']
# ['sleep', 'people', 'take', 'good', 'care', 'urself', 'tomorrow']
# ['already']
# ['thaiscb', 'sure', 'best']
# ['abcdelizabethhh', 'happy', 'birthday', 'roxxiiii']
# ['adcons', 'quotbegginquot', 'good', 'freeway', 'song']
# ['quotwho', 'took', 'badjasquot', 'quotno', 'koffiekoeken', 'youquot', 'leuke', 'reclame', 'belgiã']
# ['head', 'hurt', 'sooooo', 'blergh']
# ['ellenstafford', 'think', 'lovely', 'time', 'last', 'week', 'make', 'feel', 'better']
# ['lovely', 'rainy', 'grey', 'cold', 'weather', 'today']
# ['coming', 'food', 'right', 'back']
# ['looys', 'told', 'graduation', 'today', 'pweez']
# ['tomorrow', 'cant', 'wait', 'mummy']
# ['find', 'another', 'ï¿½600', 'next', 'month', 'fucked', 'doesnt', 'help', 'getin', 'bursary', 'shit', 'amount']
# ['valley']
# ['sweet', 'home', 'nite', 'philly']
# ['wish', 'still', 'closing']
# ['composerandreas', 'love', 'interview']
# ['sn0wrose', 'hugggggsssssss', 'love']
# ['tomziglar', 'time', 'best', 'ziglar', 'quote', 'time', 'management', 'inspire']
# ['ooking', 'apartment', 'around', 'think', 'afford', 'really', 'want', 'live', 'bummer']
# ['hhhhhh', 'aldo', 'outlet']
# ['allyeska', 'ideal', 'girlfriend', 'would']
# ['work', 'super', 'hungry']
# ['silently', 'killing']
# ['ejecting', 'food', 'substance']
# ['lost', 'follower', 'want', 'follower', 'back', 'please', 'come', 'back', 'awww']
# ['bobbiiee', 'gettombackinthelead', 'spread']
# ['sarah1991', 'presale', 'miley', 'apparently']
# ['muchmusic', 'wristband', 'mmvas', 'june', 'please', 'pick', 'love', 'showmmvas']
# ['ashlinnlua', 'ohhhh', 'ever']
# ['lizjonashq', 'love', 'storm', 'rest', 'tour', 'alone', 'miiiley']
# ['colinsato', 'tracking', 'posse', 'call', 'oppurtunity', 'quotfoundquot', 'spare', 'unlocked', 'door', 'open', 'thievessuckage']
# ['pauljchambers', 'thought', 'stage', 'work', 'youd', 'great']
# ['niciscotin', 'lazy', 'head', 'first', 'school', 'hope', 'great', 'timeand', 'hope', 'miss', 'meaaaaaaal']
# ['robkardashian', 'still', 'responding', 'favorite', 'part', 'love', 'lame', 'sorry', 'laughing', 'loud']
# ['really', 'sick']
# ['brazilian', 'right', '218pm', 'totally', 'sleeplessany', 'advice']
# ['twitter', 'sorry', 'abusing', 'month']
# ['pandadementia', 'welcome']
# ['antonio', 'mission', 'game', 'waitressing', 'huge', 'crowd', 'meaning', 'slow', 'game']
# ['followed', 'show']
# ['forpawz', 'subaru', 'maybe']
# ['martymcfly', 'mrty', 'mcfly', 'love']
# ['chool', 'start', 'monday', 'could', 'born', 'genius']
# ['fizzers', 'double', 'lolly']
# ['stinkle', 'sure', 'soul', 'ache', 'today', 'totally', 'blow']
# ['telling', 'cant', 'forever', 'love', 'free', 'take', 'pretty', 'wing', 'away']
# ['berlinessainny', 'hello', 'back']
# ['news', 'today', 'actor', 'david', 'carradine', 'died', 'condolence', 'family', 'spirit', 'find', 'peace', 'searching']
# ['jagnla', 'closer', 'everything', 'simi', 'close', 'early']
# ['laughing', 'like', 'idiot']
# ['wickedlm', 'twitter', 'logo', 'show', 'anymore', 'either']
# ['witter', 'wont', 'display', 'picture']
# ['aking', 'pasta', 'cramming', 'english', 'final', 'tomorrow']
# ['mpulsively', 'bought', 'dress', 'turned', 'good']
# []
# ['pendulum', 'awesome', '2goodbyes', 'suck', '3shut', '4toy', 'story', 'movie', '2moro', 'tired', '7aaaand']
# ['inally', 'naka', 'sarap', 'trip', 'buddy']
# ['sbirr', 'nice']
# ['soulisthegoal', 'near', 'newcastle', 'away']
# ['bring', 'cover', 'real', 'michael', 'jackson', 'laughing', 'loud', 'waaannnnnaaaa', 'damn', 'work']
# ['kandydevil', 'love', 'sleeptooi', 'slept', 'hour', 'last', 'night', 'hour', 'vigilant']
# ['orrk', 'worrk', 'worrk', 'hate', 'whole', 'every', 'weekend', 'thing']
# ['jessdanielbugay', 'daniel', 'favorite', 'planet', 'venus', 'rhyme', 'favorite', 'thing', 'world']
# ['anging', 'libby', 'love', 'much']
# ['ored', 'mind', 'laughing', 'loud']
# ['going', 'swimming', 'long', 'raining', 'indoors', 'hope', 'everyone', 'great']
# ['appier', 'ever', 'whole', 'aventura', 'full', 'song', 'album', 'even', 'come', 'myspace']
# ['scottbourne', 'nice', 'looking', 'forward', 'indepth', 'camera', 'review']
# ['rosetteadel', 'love', 'thing', 'making', 'sick', 'sleep', 'today', 'learned', 'shiz']
# ['kennynim', '32degrees', 'hope', 'cooler', 'tonight']
# ['mopro', 'bright', 'early']
# ['feeling', 'well', 'kidney', 'transplant', 'westmead', 'childrens', 'hospital', 'giving', 'kidney']
# ['watch', 'better', 'thought', 'would', 'alexis', 'threw', 'didnt', 'finish']
# ['amntherez', 'talk', 'tonitefeeling', 'lonely']
# ['eing', 'looked']
# ['tired', 'want', 'back', 'canterbury']
# ['akin', 'care', 'baby', 'shes', 'sick']
# ['ooking', 'pe0plleeeee', 'many', 'stranger']
# ['duanebrown', 'well', 'bought']
# ['rosie21', 'johnny', 'depp', 'fantastic', 'actor']
# ['shakah0lic', 'shocker', 'stefy', 'tell', 'walking']
# ['using', 'lucene', 'iterating', 'faster', 'lost', 'search', 'indexing', 'lucene']
# ['happy', 'look', 'like', 'start', 'dusting']
# ['ought', 'lens', 'online', 'spent', 'haha', 'last', 'night', 'hair', 'show', 'blast', 'come', 'thanks', 'teammate']
# ['pheliziph', 'really', 'like', 'shopping', 'need', 'food', 'well', 'hungry']
# ['oving', 'movie', 'award', 'funny']
# ['follow', 'dear']
# ['vega', 'shld', 'crime']
# ['yesterday', 'month', 'pregnant']
# ['transferring', 'pixelapnea', 'another', 'host']
# ['vannessvanwu', 'hitting', 'back', 'g00dluck', 'enj0y', 'dropby', 'manila', 'time']
# ['razormuse', 'laughing', 'loud', 'beautiful', 'seattle', 'area']
# ['till', 'management', 'laughing', 'loud']
# ['brandystrippers', 'okayi', 'else', 'find']
# ['whatdennis', 'hate', 'suck']
# ['trek', 'great', 'minor', 'detail', 'needed', 'worked', 'give', 'thumb', 'regardless']
# ['issed', 'blokesidiots', 'excited', 'weekend', 'even', 'work', 'tomorrow']
# ['damn', 'picked', 'shift', 'wink']
# ['orking', 'thesis', 'life', 'exciting']
# ['jennettemccurdy', 'incredible', 'video', 'jennette', 'amazing', 'singer']
# ['phildav', 'chance']
# ['rying', 'destiny']
# ['look', 'police', 'brutality', 'video', 'iran', 'masked', 'beating', 'crap', 'people', 'pissed']
# ['madisonlaying', 'work', 'time']
# ['novacaine', 'time', 'could', 'numb', 'crown', 'pain', 'week']
# ['eteor', 'shower', '2009', 'ready', 'action']
# ['webaddict', 'know', 'anything', 'gardening', 'except', 'like', 'weed', 'oooh', 'nice', 'rake']
# ['wanted', 'near', 'cant', 'somebody', 'owns']
# ['movie', 'award', 'proving', 'quite', 'funny']
# ['back', 'beach', 'beautiful', 'took', 'amazing']
# ['adriennej', 'facebook', 'come', 'join']
# ['ivanae', 'ahhh', 'cool']
# ['tired', 'teeth', 'hurt']
# ['jocelynheins', 'head']
# ['moon', 'trailer', 'amazing', 'taylor', 'lautner', 'like', 'whoah', 'haha']
# ['bestie', 'laughing', 'loud', 'almost', 'curfew', 'home', 'soon']
# ['chaunceycc', 'thought', 'favorite']
# ['found', 'collide', 'barnes', 'noble', 'stock', 'online', 'purchase']
# ['theronkinator', 'oooo', 'hong', 'kong']
# ['drudge', 'failed', 'tonight', 'jack', 'kemp', 'passed', 'away', 'stuck', 'flotus', 'tennies', 'weak', 'rethinking', 'worth']
# ['mickayyyla', 'borrow', 'sister', 'camera', 'cause', 'mine', 'broke']
# ['mjnypost', 'good', 'luck', 'looking', 'forward', 'interview', 'david', 'cook', 'nice']
# ['blog', 'mileyworld', 'neither', 'showing', 'getting', 'sorrrryy']
# ['twitterfon', 'making']
# ['follower', 'shall', 'make']
# ['ishes', 'everyone', 'understood', 'concept', 'bathing', 'wearing', 'clean', 'clothes']
# ['birthday', 'come', 'faster', 'every', 'year']
# ['dadned', 'even', 'mentioned', 'twitter', 'desperate', 'housewife', 'funny', 'hope', 'good', 'night', 'love']
# ['paulwerewolf', 'great', 'choice', 'paul']
# ['yoem', 'left', 'salvador', 'yesterday']
# ['holding', 'personal', 'copy', 'dftba']
# ['uncle', 'thatd']
# ['theellenshow', 'forgive']
# ['huskyjon97x', 'love', 'shark', 'like', 'teenage', 'girl', 'fandom', 'though', 'agree', 'airborne', 'toxic', 'event', 'joke']
# ['purple', 'bang', 'feelingggg', 'course', 'tiwtpic', 'isnt', 'working', 'guyz', 'wait', 'till', 'back']
# ['reating', 'twitter', 'though', 'feel', 'like', 'hangover', 'witch', 'aint', 'possible']
# ['omcast', 'effin', 'hate', 'come', 'back', 'internet', 'maybe', 'fact', 'live', 'boonieshmm']
# ['atampt', 'tweet', 'break', 'upset', 'about', 'keepn', 'peep']
# ['barely', 'keep', 'open', 'getting', 'hour', 'sleep', 'good', 'youbut', 'anyway']
# ['back', 'blocked', 'nose', 'frozenn', 'best']
# ['markboardman', 'heard', 'never', 'listened', 'hasi', 'talk', 'today']
# ['please', 'anyone', 'torn', 'direction', 'need', 'make', 'clone']
# ['musgravejw', 'dont', 'internet', 'house', 'message', 'going']
# ['wazza12', 'bourne', 'bluray', 'trilogy', 'mate', 'amazing', 'franchise', 'flick', 'good', 'blue']
# ['going', 'visit']
# ['urself', 'family', 'force', 'immense', 'band']
# ['finished', 'morning', 'test', 'work', 'like', 'wanted', 'going', 'move', 'week', 'list']
# ['ozdj', 'must', 'pretty', '7366kms', 'nice']
# ['xgravity23', 'already', 'next', 'season', 'going', 'last', 'season']
# ['hilling', 'like', 'lazy', 'saturday']
# ['chii', 'renaissance', 'festival', 'fairburn', 'north', 'atlanta']
# ['atmasphere', 'explains', 'wonder', 'ngage', 'sisx', 'file', 'leak']
# ['hollisthomases', 'love', 'love', 'window', 'adobe', 'application', 'like', 'install', 'anywhere']
# ['annot', 'understand', 'math']
# ['tofumei', 'cant', 'usss', 'laughing', 'loud', 'seriously', 'though', 'getting', 'last', 'nerve', 'nice', 'lame']
# ['great', 'trying', 'enjoy', 'good', 'night', 'though', 'mention', 'amara', 'throwing', 'tantrum']
# ['geeno33', 'thats', 'good', 'hear', 'plan', 'today']
# ['mogiah', 'like', 'almost', 'midnight', 'hope', 'tonight']
# ['orked', 'buggered']
# ['etting', 'killed', 'capa', 'bullshit']
# ['akomuzikera', 'damn', 'missed']
# ['uckn', 'mondayswtf', 'happened', 'weekend']
# ['awake', 'even', 'though', 'totally', 'exhausted', 'ready', 'home']
# ['work']
# ['nimalraj', 'awhhhhh', 'also', 'want']
# ['fifi1976', 'lucky', 'envy', 'wish', 'away', 'though']
# ['giulianarancic', 'love', 'giuliana', 'watch', 'allllllllll', 'time', 'everytime', 'come', 'home', 'work', 'watch', 'news']
# ['anyone', 'mitchels', 'free', 'concert', 'last', 'night', 'miley', 'sweet', 'flew', 'arkansas', 'support']
# ['danielmacdonald', 'reviewing']
# ['mien84', 'hope', 'feel', 'better', 'soon', 'would', 'hand', 'stuff']
# ['gulpanag', 'missed']
# ['javajay', 'suck', 'existant', 'cock']
# ['hurt', 'swallow']
# ['horrible', 'tired', 'coughing']
# ['midlifechick', 'quotthey', 'face', 'every', 'turn', 'themquot', 'accused', 'seeing', 'everywhere', 'many', 'year']
# ['trentreznor', 'howd', 'show', 'chicago', 'friday', 'missed']
# ['joeynigro', 'sound', 'good', 'write', 'like', 'paper', 'weekend', 'week', 'kinda', 'much', 'time']
# ['home', 'actually', 'feel', 'good', 'nice', 'weekend', 'honey', 'though']
# ['outube']
# ['atching', 'seven', 'pound', 'going', 'solid', 'rock', 'really', 'wonderful', 'people']
# ['airconditioned', 'office', 'drinking', 'moment', 'worry', 'fair', 'share', 'suffering', 'home']
# ['jpfurry', 'poor', 'john', 'happens', 'play', 'fruit', 'microwave', 'seriously', 'though', 'seen', 'doctor']
# ['friend', 'quoti', 'point', 'myspace', 'twitter', 'facebookquot', 'well', 'thats', 'opinionmy', 'good', 'entitled']
# ['mshiphopboston', 'shit', 'need', 'well', 'heat', 'street', 'fire', 'working', 'like']
# ['jackalltimelow', 'maybe', 'meno']
# ['till', 'feeling', 'poorly']
# ['xxxdestinyday', 'ohhh', 'kool', 'shooting', 'buddy', 'photo', 'know']
# ['elisacar', 'know', 'coming', 'back', 'athens']
# ['tired', 'last', 'night', 'dont', 'sleep', 'wellso', 'good', 'night']
# ['cheer', 'practice', 'everyday', '8am12pm']
# ['lolitadollie', 'tweetie', 'best', 'free']
# ['part', 'moving', 'suck', 'everything', 'packed', 'sitting', 'bare', 'lounge', 'room', 'feel', 'cold', 'lonely']
# ['mileycyrus', 'wooooo', 'congratulation', 'best', 'movie', 'song', 'totally', 'deserved']
# ['infamousladyt', 'polyacrylate', 'respiratory', 'system', 'baby', 'clothdiapers']
# ['inally']
# ['therealjayrome', 'nasty']
# ['cherylharrison', 'first', 'thing', 'going', 'punch', 'ovary', 'drink', 'beer']
# ['medium', 'miss', 'sososo', 'muchhh', 'sexybye']
# ['kucharo', 'capitalist', 'fact', 'wealthy', 'enuf', 'keep', 'ignoring', '450gal', 'life', 'tank', 'every', 'mile', 'suck']
# ['addicted', 'twitter', 'thing']
# ['wasnt', 'failbut', 'wasnt', 'first', 'either', 'deeply', 'resent', 'revised', 'easy']
# ['exam', 'celebrating', 'pizza']
# ['istening', 'ciccillejus', 'quotmartinaquot', 'brings', 'many', 'memory', '2004', 'nostalgia', 'even', 'candytron', 'kick', 'already']
# ['home', 'think', 'ironman', 'finish', 'work', 'online', 'realized', 'popcorn', 'arrrgh']
# ['lissascott', 'wonderful', 'time', 'well', 'miss', 'office']
# ['foot', 'front', 'soon', 'yull', 'walkin', 'door']
# ['anagibson', 'haha']
# ['rojanlovesyou', 'know', 'smelly', 'park', 'america', 'even', 'nice', 'park']
# ['mine', 'changed', 'hahaa']
# ['rhettmatic', 'happy', 'birthday']
# ['layed', 'saintsrow2', 'hour', 'today', 'crazy', 'game', 'good']
# ['ereal', 'harry', 'potter', 'life']
# ['delicious', 'breton', 'crepe', 'dippin', 'breakfast', 'raphaela', 'amanda']
# ['leanne0710', 'look', 'pure', 'stole', 'sunspex', 'bint']
# ['nausicaavalley', 'calculated', 'ingredient', 'worth', 'time', 'cooked', 'dear']
# ['peterfacinelli', 'would', 'love', 'chair', 'backing', 'twitter', 'much', 'sorry', 'follow', 'peterfacinelli']
# ['hurt', 'foot', 'whilst', 'doin', 'exercise', 'cramp', 'hurt', 'much', 'pressure']
# ['back', 'roastin', 'mallow']
# ['spine', 'hurt', 'much']
# ['mimistyle', 'feeling', 'would', 'vote', 'york', 'city', 'totally', 'girl', 'sorry', 'still']
# ['osters', 'poster', 'poster', 'warped', 'flapping', 'poster', 'need', 'come', 'stored', 'general', 'election', 'month', 'le09']
# ['believe', 'game', 'ended', 'team', 'close', 'winning']
# ['leahxo', 'fucking', 'leave', 'rude', 'rude', 'rude', 'hate', 'passion']
# ['miss', 'boyfriend']
# ['scored', 'series', 'match', 'today', 'going', 'cool', 'srry', 'contest', 'time']
# ['kelleymcdonell', 'thanks', 'come', 'visit', 'penneys', 'working', 'weekend']
# ['elpollolocoinc', 'going', 'state', 'verified', 'store', 'locator']
# ['funkyfairy30', 'morning', 'today', 'touch', 'lurgy']
# ['oing', 'quotthe', 'work', 'artquot', 'conference', 'surrey', 'todayi', 'excited', 'hungry', 'idea', 'different', 'perspective']
# ['tudying', 'social', 'study', 'wahhhh', 'suck']
# ['extra', 'photographer']
# ['nijumohan', 'well']
# ['really', 'abandoned', 'twitter', 'back', 'school', 'finally', 'take', 'care', 'career']
# ['call']
# ['twitterland', 'wave']
# ['lilyroseallen', 'fuck']
# ['nother', 'hour', 'work']
# ['reading', 'work', 'today', 'want', 'stay', 'noelles']
# ['martinjmurray', 'coming', 'heavy']
# ['randypeterman', 'laughing', 'loud', 'tell', 'girl', 'think', 'wearing']
# ['late', 'door', 'locked']
# ['etting', 'ready', 'lunch', 'jaclyn']
# ['jeffrey', 'moving', 'karaoke', 'tour', 'stopping', 'boulder']
# []
# ['iversity', 'congratulation', 'deserved', 'brilliant', 'stavros', 'flatly', 'mint', 'loved']
# ['dewzpingpong', 'wait', 'live', 'wait']
# ['jadoremarmite', 'well', 'hope', 'better']
# ['sethsimonds', 'found', 'effective', 'neatly', 'inhale', 'breakfast', 'cereal', 'oversized', 'coffee']
# ['drummit2summit', 'course', 'protester', 'clearly', 'threatening', 'environment', 'drunk', 'fool', 'injuring', 'wildlife', 'awesome']
# ['kaliyahpjones', 'lolthats', 'kinda', 'discourages', '4rom', 'goin', 'shit', 'wack']
# ['danspring', 'evening', 'help', 'wordpress', 'support']
# []
# ['00th', 'update']
# ['evening', 'front', 'nothing', 'strenuous', 'school', 'morning']
# ['00th', 'twitter', 'update']
# ['stormdragonblue', 'didi', 'miss', 'david', 'lynch', 'epic', 'movie', 'dune', 'wait', 'quotepic', 'moviequot', 'quotdavid', 'lynchquot', 'together', 'jeje']
# ['britain', 'talent']
# ['guess', 'ready', 'school']
# ['appy', 'father', 'ever', 'life', 'wish']
# ['sleepy', 'finding', 'hard', 'keep', 'open']
# ['atching', 'bored']
# ['oday', 'sucked', 'nauseous', 'feeling', 'better', 'hungry', 'everything', 'closed', 'might']
# ['miss', 'already']
# ['realized', 'live', 'philly', 'father', 'probably', 'going', 'afterall', 'panda']
# ['gimchoa', 'love', 'sushi', 'salmon', 'sashimibut', 'tapeworm', 'outbreak', 'somewhere', 'recently', 'groooosssscary']
# ['nathanmillson', 'probs', 'welcome', 'back']
# ['arezou007', 'shes', 'leaving', 'tomorrow', 'dont', 'shoot', 'outside', 'much', 'math', 'maaan', 'yikes', 'help']
# ['mouse', 'work', 'trying', 'hunt', 'catch', 'caught', 'nothing']
# ['sucky', 'ltgasgt']
# ['peter', 'piper', 'noah', 'birthday', 'time', 'except', 'half', 'game', 'order']
# ['mommie', 'called', 'girl', 'ripped', 'half', 'window', 'screen']
# ['tarting', 'become', 'friend', 'biology', 'tomorrow', 'make', 'friend', 'chemistry', 'physic']
# ['eelin', 'greatim', 'goin', 'college', 'july', 'super', 'happy', 'solo', 'relationship', 'dramathx', 'messing', 'brandonlol']
# ['octors', 'appointment', 'today', 'freaking']
# ['starting', 'feel', 'little', 'better', 'still', 'need']
# ['want', 'sick', 'feelin', 'away']
# ['annisatadiyana', 'ahhhhhhhhhhhh', 'love', 'song', 'although', 'jimmy', 'singing', 'part', 'suck']
# ['erby', 'challenge', 'keep', 'racehorse', 'slaughter', 'work']
# ['good', 'broke', 'router']
# ['think', 'star', 'struck', 'famous']
# ['there', 'storm', 'coming', 'harry', 'like', 'last', 'time', 'change', 'harry', 'michelle', 'black', 'think', 'goin', 'stormy', 'later']
# ['elaxing', 'home', 'nice']
# ['pending']
# ['quotyeah', 'douche', 'brian', 'douche', 'come', 'back', 'douchequot']
# ['please', 'someone', 'added', 'laughing', 'loud']
# ['jmilles', 'yeah', 'guess', 'right']
# ['ttpwwwfotologcomoficialnickjonas', 'club', 'oficial', 'chile']
# ['idnt', 'managed', 'participate', 'morning', 'exercise', 'waited', 'panadol', 'said', 'slight', 'feverso', 'rest']
# ['ausious', 'feel', 'sick', 'dizzy']
# ['daniel2beck', 'trying', 'nice', 'rain', 'though', 'need', 'holiday']
# ['starryeyed', 'sorry', 'hear']
# ['oldeatingschooll']
# ['made', 'yummy', 'banana', 'bread', 'grandma', 'recipe', 'today', 'sadly', 'enough', 'left', 'take', 'work', 'tomorrow']
# ['cwalski', 'sorry', 'mate', 'connecting', 'canberra', 'hope', 'well']
# ['feel', 'like', 'everything', 'miss']
# ['ostponed', 'abandoned']
# ['urnt', 'finger']
# ['pariskennedy', 'wish', 'could', 'make', 'maybe', 'someday']
# ['isters', 'dance', 'competition', 'today', 'shes', 'come', 'rock', 'roll', 'woohoo', 'dance', 'heart', 'solo']
# ['omeone', 'united', 'state', 'like', 'glob']
# ['juliewunder', 'great', 'lake', 'weather', 'love', 'necklace', 'morningvery', 'bold']
# ['back', 'sooo', 'tired', 'right']
# ['plaid', 'shirt', 'today', 'would', 'proud', 'changed', 'though', 'something', 'ladylike', 'feminine', 'feel', 'pretty']
# ['makennanomad', 'know', 'want', 'everyone', 'happy', 'happen', 'time', 'seems']
# ['sunburn', 'damn', 'medicine']
# ['nxth', 'unlucky', 'come', 'back']
# ['theswellers', 'come', 'week', 'june27th', 'need', 'ride', 'showww']
# ['ibrary', 'bestfriend']
# ['time']
# ['marjorielu', 'still', 'miss']
# ['think', 'goin', 'rain', 'going', 'tesco', 'shopping', 'exciting', 'option', 'louie', 'even', 'dressedbored']
# ['eilonwylovegood', 'nocturnal', 'night', 'sleep', 'till', 'like']
# ['lolucy', 'wish', 'lucy', 'friend', 'haha']
# ['pleased', 'bodie', 'took', 'doggy', 'tinkle', 'could', 'stay', 'inside', 'front', 'heater', 'telly']
# ['wanzai', 'yeah', 'prof', 'also', 'complains', 'call', 'duty']
# ['caught', 'frost', 'nixonmy', 'kinda', 'movie']
# ['absolutlyariana', 'girl', 'like', 'proud', 'miss', 'tradeshow', 'done', 'really', 'together', 'soon']
# ['hour', 'still', 'grass', 'want', 'listening', 'prematch', 'commentary']
# ['rain', 'happen', 'hate', 'want', 'pool', 'golf', 'course']
# ['andreamv', 'thank', 'comment', 'artwork', 'lovely', 'week']
# ['wyclef', 'hows', 'diet', 'going', 'avoiding', 'cooky', 'burger', 'today']
# ['bloody', 'late', 'work', 'home', 'early']
# ['maschad', 'laughing', 'loud', 'okay']
# ['happy', 'home', 'kind', 'messed']
# ['finish', 'lastnice', 'girl', 'finish', 'last']
# ['rouska', 'story', 'next', 'time', 'running', 'late', 'tube']
# ['looking', 'forward', 'tomorra']
# ['sebflyte', 'worried', 'irish', 'bussiness', 'going', 'brother', 'producer', 'live', 'rugby', 'team']
# ['plate', 'second', 'steal', 'schnitzel', 'schnitzelless']
# ['ikssss', 'good', 'good']
# ['orlando', 'hour', 'killed', 'phone', 'using']
# ['sigitt', 'maybe', 'sigh', 'tweetdeck', 'acting', 'funky']
# ['busy', 'entire', 'come', 'onlinetill', 'private', 'frnz', 'call', 'cell', 'restcan', 'offline']
# ['good', 'evening']
# ['jasondcurry', 'flying', 'back', 'tomorrow', 'morning', 'flight', 'work', 'tomorrow']
# ['louisvillebobby', 'awwww', 'like', 'first', 'virtual', 'cheap', 'date', 'problem', 'crazy', 'huge', 'drink', 'holder']
# ['therealarsenix']
# ['loraleonard']
# ['lindakazahlocke', 'brown', 'cutey']
# ['monthslt3', 'hanging', 'trevor', 'tonight']
# ['thomasjen4', 'sure', 'thing', 'good', 'luck', 'finishing', 'everything']
# []
# ['ttps729photobucketcomalbumsww299jbluver4ever95icons', 'icon']
# ['orcfiend', 'tell', 'would']
# ['home', 'nina', 'house', 'movie', 'awesome', 'school', '2mmorow', 'ewwwwwwwww']
# ['english', 'exam', 'siting', 'back', 'realxing', 'garden', 'sunbathing', 'proper', 'unbelievable']
# ['sallybish']
# ['pplesauce', 'hungry', 'maybe', 'woke', 'four', 'today', 'lazy', 'slice']
# ['christinafaith', 'come', 'honda', 'nissan', 'honda', 'online', 'tongue', 'glad', 'enjoyed', 'laughing', 'loud']
# ['zaferroni', 'damn', 'gentle', 'scuffing']
# ['openly', 'embarassed', 'dont', 'mind', 'excited', 'tomorrow']
# ['always', 'insit', 'wearing', 'shoe', 'know', 'hurt', 'foot']
# ['eeklong', 'visit', 'parent', 'going', 'well', 'flying', 'wishing', 'weather', 'better']
# ['finished', 'watching', 'marley', 'matt', 'almost', 'sleepy', 'time']
# ['someone', 'adrink', 'faaa', 'real']
# ['arsbars', 'cant', 'tweet', 'blocked']
# ['cosmiclagoon', 'ironically', 'sunny', 'warm', 'vancouver', 'find', 'refreshing']
# ['appy', 'queen', 'birthday', 'everyone', 'celebrate', 'melbourne', 'winloss']
# ['awesome', 'broken']
# ['followddt', 'talk', 'food', 'nothing', 'house', 'nothing']
# ['morning', 'nice', 'today', 'pool']
# ['charlottez6', 'awesome', 'movie', 'hungry']
# ['naanad', 'thanks', 'sure', 'good', 'luck', 'interview', 'today']
# ['feeling', 'failed', 'final', 'parking', 'meter', 'running', 'rushed']
# ['feel', 'like', 'working', 'much', 'today']
# ['justinejones', 'sorry', 'tweet', 'effect', 'much', 'dont', 'like', 'feel', 'free', 'follow']
# ['babymakes7', 'damn', 'shame', 'someone', 'talented', 'amazing', 'clark', 'gable', 'legacy', 'born', 'death']
# ['casrangers669', 'great', 'week', 'cassi']
# ['keep', 'busy', 'hour']
# ['enamoredsoul', 'kiss', 'kiss', 'honey', 'kind', 'loveliest', 'spirit', 'always', 'positive', 'compassionate']
# ['swiftkaratechop', 'jealous', 'wait', 'friend', 'come', 'mcdonalds', 'taking', 'forever']
# ['left', 'little', 'think', 'quite', 'understand']
# ['bradpeczka', 'missed', 'gone']
# ['sleep', 'fall', 'asleep', 'road']
# ['rnbgorilla', 'would', 'like', 'apart', 'campaign']
# ['iheartiysis', 'easy']
# ['oing', 'bedfinally', 'tweet', 'dream', 'everyone']
# ['andom', 'know', 'give', 'shit', 'feeling', 'overwhelmed', 'little']
# ['nyone', 'ggive', 'dollar', 'jonas', 'shirt', 'short']
# ['eugenechua', 'dude']
# ['feel', 'well']
# ['hypnotized805', 'good', 'morning', 'sleep', 'well']
# ['dobrydendavid', 'hope', 'expensive']
# ['extremely', 'lonely', 'today', 'want']
# ['usband', 'making', 'waffle', 'much', 'love', 'husband']
# ['vatt', 'lvatt', 'lvatt', 'lvatt', 'lvatt', 'linesvinesamptryingtimes', 'finally', 'ampamp', 'already', 'itunes']
# ['argel319', 'know', 'also', 'dude', 'lost', 'router', 'signal', 'connect']
# ['etaksha', 'apologise', 'wrong', 'math', 'haha', 'like', 'blow', 'worth']
# ['chowderrr03', 'pala', 'always', 'forgot', 'phils']
# ['timryancw', 'good', 'thanks', 'hate', 'twitter', 'shyte']
# ['luvb', 'guess', 'found', 'love', 'especially', 'filipina']
# ['bought', 'book', 'back', 'home', 'read', 'since', 'book', 'store', 'closing']
# ['wont', 'link', 'work']
# ['want']
# ['done', 'cutting', 'grass', 'well', 'almost', 'done']
# ['sooooo', 'madbut', 'cant', 'anything', 'grrrrr']
# ['carebear017', 'school', 'miss', 'gtlt']
# ['written', 'realy', 'long', 'text', 'pushed', 'send', 'sundely', 'outlooked', 'everthing', 'nothing', 'much']
# ['lazy']
# ['earth', '616s', 'wiley', 'maniac', 'vinylsnothing', 'play']
# ['homeampmum', 'decided2have', 'faint', 'attacki', 'obviously', 'panickedampcalled', 'ambulanceshe', 'really', 'angry', 'meampsaid', 'stupid']
# ['etting', 'ready', 'work']
# ['eally', 'excited', 'show', 'come', 'soon', 'enough']
# ['istening', 'night', 'hubby', 'teaching', 'julia', 'fall', 'asleep', 'hope', 'learns', 'soon']
# ['friggen', 'tissue', 'suck']
# ['floating', 'adriatic', 'right', 'nowmiss']
# ['tutoring', 'dinner', 'watching']
# ['criistina26', 'concertjust', 'entering', 'pista', 'concert', 'pista']
# ['school', 'tomorrow', 'week', 'summer', 'holiday', 'america', 'come']
# ['wish', 'every', 'weekend', 'could', 'awesome', 'everyones', 'plan', 'tomorrow']
# ['atraiocatharsis', 'haha', 'bitchh', 'laughing', 'loud', 'love']
# ['morning', 'good', 'afternoon', 'friend', 'hows', 'everyone', 'today', 'beautiful', 'chicago', 'much', 'first', 'caffeine']
# ['would', 'like', 'know', 'quotborderline', 'assquot', 'holla']
# ['willow0818', 'true', 'would', 'said', 'something', 'wait', 'something']
# ['kitsunethoughts', 'well', 'hopefully', 'move']
# ['best', 'taylor', 'swift']
# ['early', 'working', 'lazy', 'sunday', 'stupid', 'work']
# ['hartleyglobe', 'great', 'agenda', 'tell', 'watch', 'back', 'want', 'take']
# ['mihaela4021', 'summer', 'vacation', 'yeeyy']
# ['fev88', 'dunno', 'anything', 'else', 'looked', 'mcdonalds']
# ['veryone', 'gone', 'home', 'quiet']
# ['everyone', 'fathersday', 'tomorrow', 'broke']
# ['jessierosexo', 'hahaaha', 'need', 'sunday', 'dinner', 'today', 'learned', 'half']
# ['atching', 'sexy', 'white', 'tree', 'hill']
# ['fantabulous', 'weekend', 'tired', 'hell', 'back', 'work', 'gone', 'earlier']
# ['mcflygal', 'except', 'cant']
# ['horrible', 'mood', 'help', 'fiance', 'make', 'better']
# ['ramcnn', 'working', 'good', 'stuff', 'carter', 'nice', 'video', 'security', 'hour']
# ['wake', 'hour', 'eating', 'tired', 'barely', 'speak', 'swollen', 'throat', 'humbug']
# ['noght', 'time', 'late', 'night', 'last', 'night', 'tired']
# ['christianacting', 'watch', 'ilyolivia', 'video', 'beast']
# ['kingspoonian', 'mentioned', 'well', 'initially', 'character', 'dammit']
# ['orry', 'know', 'happens', 'click']
# ['msterdam', 'cancelled', 'free', 'bird', '26th', 'june']
# ['evieevev', 'used', 'ipod', 'deleted', 'download', 'waslike']
# ['jillycl', 'good', 'morning']
# ['finally', 'getting', 'book', 'shelf']
# ['ransformers', '2wow', 'good', 'went', 'numb', 'though', 'hayfever', 'suck']
# ['hour', 'kneading', 'rolling', 'fresh', 'pasta', 'behest', 'refuse', 'sauce']
# ['kimkardashian', 'noooo', 'show', 'watch', 'sunday']
# ['sleepier', 'hungry', 'going', 'without', 'supper', 'gnight', 'everyone']
# ['here', 'really', 'nothing', 'hear', 'radio']
# ['hell', 'website', 'homepage', 'position', 'turn', 'customer', 'away']
# ['feel', 'like', 'barfing', 'worked']
# ['little', 'masi', 'isnt', 'feeling', 'well']
# ['awesome']
# ['oooood', 'morning']
# ['heykendall', 'lucky', 'life', 'suck']
# ['sashawolff', 'wish', 'someone', 'would', 'told', 'today', 'organizer', 'national', 'recess', 'work']
# ['mossyrants', 'couple', 'best']
# ['cultn', 'yeah', 'thought', 'might', 'well']
# ['sheridanpaige', 'nahh', 'lool', 'first', 'lesson']
# ['akpoff', 'feel', 'pain', 'atampt', 'internet', 'home', 'work', 'network', 'painfully', 'slow', 'since', 'last', 'week']
# ['rying', 'used', 'summerhave', 'stomach', 'like', 'forgetting', 'something', 'sure', 'away', 'august']
# ['rinking', 'ciroc', 'tired']
# ['twilight', 'like', 'every', 'award', 'went', 'kristen', 'funny', 'love', 'whole', 'cast', 'laughing', 'loud']
# ['iswagster', 'cant', 'help', 'itdnt', 'muchlol']
# ['chaselisbon', 'iphone', 'retweet', 'post', 'meant', 'private', 'laughing', 'loud']
# ['finally', 'roll', 'time', 'stop', 'weird', 'love']
# ['ilmingggg', 'finalllly']
# ['oing', 'dinner', 'molly', 'mandy', 'noodle', 'party', 'time', 'emma', 'good', 'night']
# ['selavy', 'mulberry', 'mountain', 'also', 'cabin', 'hold', 'would', 'bear', 'maybe', 'next', 'time']
# ['teachakidd', 'would', 'yankee', 'game', 'jose']
# ['jackosborne', 'yeah', 'think', 'wait', 'really', 'find', 'much', 'info', 'feature', 'though']
# ['blew', 'another', 'speaker']
# ['alot', 'carnival', 'wish', 'going', 'longer']
# ['unknownorigin', 'believe', 'thought', 'would', 'look', 'ranger', 'scored', 'feel', 'like', 'fault', 'laughing', 'loud']
# ['izushima', 'hiros', 'acting', 'improved', 'look', 'better', 'hana', 'kimi', 'ikuta', 'toma', 'still', 'best', 'cute', 'gtlt']
# ['avin', 'headache', 'suckks']
# ['ironpatriot', 'haha', 'boyfriend', 'know', 'miss', 'blogtv']
# ['supercomputer', 'charl', 'tomorrow', 'even', 'bothered', 'back', 'school', 'fucking', 'year', 'volunteer']
# ['oing', 'sleeeeep', 'sweeeeet', 'dream', 'twittererers']
# ['losing', 'follower']
# ['class', 'pool', 'sunny', 'another', 'tstorm', 'come']
# ['elping', 'ross', 'move', 'theyre', 'house']
# ['absolutraia', 'hehe', 'think', 'signed', 'installed', 'ubertwitter', 'phone']
# ['sick', 'going', 'whale', 'watchingi', 'hope', 'whaleys', 'sick']
# ['fiiiiiine']
# ['yler', 'hilton', 'sexy', 'beast']
# ['gross', 'hayfever', 'suck', 'working', 'double', 'shame', 'beautiful', 'though', 'cosmos', 'movie']
# ['quotyouth', 'campquot', 'parent', 'favorite', 'time', 'year']
# ['gottaloveswift', 'thank', 'mean', 'alot']
# ['katesheppard', 'kidding', 'monsoon', 'season', 'rubber', 'boot', 'sprung', 'leak']
# ['borededup', 'actually', 'plenty', 'screen', 'cleaning', 'intern']
# ['nelip', 'feel', 'pain', 'xactly', 'mean']
# ['smpetersen', 'cute', 'feel', 'like', 'lost', 'little', 'friend']
# ['degree', 'outside', 'wished', 'student', 'working', 'point', 'could', 'lake', 'today']
# ['studiotwin', 'really', 'packing', 'fudge']
# ['julesyog', 'know', 'awful', 'poor', 'donal', 'interesting', 'ahead', 'tomoz']
# ['permission', 'really', 'really', 'really', 'like', 'someone', 'remainder', 'mean']
# ['catherineloup', 'soces', 'idem']
# ['beach']
# ['kinda', 'weird', 'youre', 'lost', 'youu', 'probably', 'part', 'town', 'laughing', 'loud']
# ['emma', 'moderate', 'size', 'hole', 'heartthere', 'chance', 'could', 'heal', 'ownbut', 'could', 'need', 'surgerymy', 'poor', 'baby', 'girl']
# ['aving', 'skirt', 'month']
# ...
# ['lose', 'tonight', 'sunday', 'funday', 'lunch']
# ['prime', 'minister', 'alreadygotta', 'take', 'showerhate', 'fact', 'monday', 'approaching', 'everytime', 'look', 'clock']
# ['already', 'wait', 'thur']
# ['30stmluva', 'oknow', 'sweet', 'dream']
# ['nother', 'blackout', 'phone', 'connection', 'people', 'time']
# ['hella', 'walk', 'today', 'today']
# ['idea', 'submit', 'site', 'wolfram', 'alpha', 'search', 'thing', 'work', 'like', 'note', 'done', 'zero', 'research']
# ['alyab', 'hope', 'amazing', 'time', 'hawaii', 'burned', 'crisp']
# ['sore']
# ['theduckie', 'hate', 'nowi', 'used', 'love', 'made', 'like', 'hated', 'itand', 'look', 'like', 'anymore']
# ['shiftywooten', 'denied', 'another', 'card']
# ['sapphiredorian', 'laughing', 'loud', 'blonder', 'though']
# ['ingin', 'song']
# ['doin', 'show', 'august', '15th', 'chicago', 'quottaste', 'chicagoquot', 'weekend']
# ['think', 'matt', 'stupid']
# ['ookin', 'forward', 'liverpool']
# ['fjejbgrtbgrbgkjhrtgk', 'worst', 'friday', 'night', 'ever']
# ['fact', 'clutz', 'news', 'tripped', 'walking', 'downstairs', 'landed', 'good', 'news', 'think']
# ['ashleyraye', 'special', 'place', 'hell']
# ['sunday', 'mean', 'favourite', 'week', 'life', 'coming']
# ['gottaviani', 'cool', 'favorite', 'tune', '2003', 'interestingly', 'waiting', 'remix']
# ['home', 'draw', 'thing', 'twitter', 'tell', 'draw', 'first', 'three', 'people', 'reply', 'laughing', 'loud']
# ['going', 'auction', 'special', 'item', 'soon', 'feesshjpping', 'bcspca']
# ['shinybiscuit', 'know', 'tweaked', 'read']
# ['playinblackkeys', 'yeah', 'miss', 'send']
# ['katiberz', 'recommended', 'genicom', 'work']
# ['roderickgubla', 'like', 'wizard', 'hush']
# ['semipenguin', 'good', 'morning', 'duane', 'long', 'since', 'written', 'understand', 'week']
# ['vbrown', 'thank', 'hour']
# ['night', 'america', 'gnight', 'california', 'gnight', 'angeles', 'gnight', 'twitter', 'sleep', 'canâ´t', 'couse', 'need', 'post']
# ['glinner', 'seem', 'underestimate', 'public', 'capacity', 'sloth', 'google', 'like', 'click', 'away']
# ['lonely', 'keep', 'company', 'female', 'orleans', 'louisiana']
# ['cant', 'buterfly', 'away', 'espsholy', 'love']
# ['desperately', 'work', 'roll', 'across', 'business']
# ['olapse', 'cloudy', 'laughing', 'loud']
# ['eard', 'youth', 'concert', 'wish', 'able', 'made', 'jealous']
# ['jennyduncandew1', 'think', 'better', 'excuse', 'party', 'trip']
# ['theaterdreamer', 'zebra', 'print', 'sunglass', 'thought', 'know', 'would', 'love', 'husband']
# ['oves', 'semester', 'senior', 'coming', 'back', 'well', 'missed']
# ['hree', 'video', 'youtube', 'mister', 'dylan', 'atkinsongt', 'watch', 'comment', 'subscribe', 'cant', 'wait', 'till', 'tomorrow']
# ['robson', 'jerome', 'playlist', 'deeply', 'deeply', 'ashamed']
# ['phoned', 'coming', 'thursday']
# ['sarahmerion', 'although', 'probably']
# ['joeymcintyre', 'tell', 'settled', 'word', 'settle', 'tenebrous']
# ['paulagd', 'shit', 'hahaa', 'hope', 'nick', 'change']
# ['feelin', 'well']
# ['kreacheryl', 'love', 'whoever', 'ruining', 'sleep', 'eventually', 'sleep', 'real', 'fucked']
# ['rossing', 'back', 'long', 'line']
# ['alleykate', 'awhhh', 'bbabyyyy', 'come', 'hereeeeeee', 'haha', 'imiss', 'crazyyy']
# ['brooklynadam', 'sorry', 'meant', 'taco', 'shack']
# ['atching', 'doctor', 'dolittle']
# ['weetdeck', 'boot']
# ['nother', 'week', 'start', 'want']
# ['think', 'crytell', 'huuuurt', 'feel', 'like', 'right', 'nowyou', 'knowthe', 'love']
# ['hlsidle', 'went', 'november', 'tried', 'tune', 'hank', 'film', 'stood', 'next', 'russell', 'brand']
# ['french', 'france', 'written', 'honk', 'porky', 'back', 'taker']
# ['whitecottage', 'thanks', 'recos', 'know', 'suggestion', 'love', 'fume', 'bistro', 'villa', 'corona']
# ['much', 'work', 'weekend']
# ['eeling', 'better', 'today', 'takin', 'cough', 'drop', 'microwave', 'water', 'super', 'work', 'blessed']
# ['michichan', 'hungry']
# ['ading', 'river', 'still', 'love', 'sooo', 'beautiful']
# ['thing', 'sick', 'organize', 'geek']
# ['jbielofficial', 'jessica', 'really', 'please', 'happened', 'movie', 'coming']
# ['peta', 'foundation', 'demand', 'maximum', 'sentence', 'decapitator', 'poor', 'mogggies']
# ['snobahr', 'understand', 'liking', 'fear', 'vibrator', 'stun']
# ['leaning', 'room', 'entire', 'closet', 'restroom']
# ['idontfakedafunk', 'yeah', 'like', 'million', 'time', 'worked', 'showed', 'right', 'away']
# ['lord1412', 'good', 'luck', 'best', 'coming', 'exam']
# ['todaywas', 'beach', 'really', 'burntthat', 'sucked']
# ['mileycyrus', 'support', 'award', 'indonesian']
# ['recipegirl', 'weight', 'loss', 'good', 'except', 'muscle', 'loss', 'hopefully', 'back', 'athlete', 'status', 'soon']
# ['spsweetsunshine', 'oiiiiii', 'exciting', 'noooooo', 'keep', 'safe', 'sorry', 'posting', 'going']
# ['weekend']
# ['hoonuu', 'would', 'thionk']
# ['eaded', 'gourmet', 'depot', 'hope', 'bring', 'discontinued', 'stainless', 'bosch', 'porsche', 'design', 'kettle', 'back', 'life']
# ['janetbarclay', 'sound', 'great', 'meet', 'woohoo']
# ['whiteblouse', 'please', 'feel', 'better']
# ['sandigrr34', 'tivo', 'didnt', 'record', 'weed']
# ['persiankiwi', 'worried', 'glad', 'back', 'iranelection']
# ['eddyherrera', 'following', 'following', 'unfollowed', 'cause', 'think', 'following', 'meexplain']
# ['slack', 'twitter', 'better', 'week']
# ['randomcrazyawkwardtrue', 'supposed', 'sleeping', 'goodnight']
# ['feel', 'like', 'dream', 'crushed']
# ['makelena', 'save', 'tweet', 'internet', 'traffic', 'file', 'fuller', 'slower', 'hope', 'help']
# ['18th', 'degreesi', 'putting', 'winter', 'clothes', 'away', 'wearing']
# ['jordanknight', 'showering', 'overrated', 'soaking', 'time', 'much', 'better', 'since', 'leaving', 'soon']
# ['dropped', 'airport', 'back', 'work', 'guess']
# ['kizmetbaby', 'sorry', 'work', 'sunday']
# ['johnnyikon', 'look', 'thats', 'crazy', 'suit', 'britney']
# ['stopped', 'leave']
# ['slimfast', 'chocolate', 'cookie', 'dough', 'help', 'stave', 'hunger', 'double', 'chocolate', 'maybe', 'body', 'chem', 'talking']
# ['view']
# ['tube', 'video', 'jbyoutube', 'watch', 'cherub', 'boot', 'camp', 'bringjbyoutubeback']
# ['loser1830', 'pretty', 'cool', 'school', 'like', 'year', 'back', 'else']
# ['charlesroper', 'rather', 'sometimes', 'genius', 'sometimes', 'plain', 'dumb', 'instead', 'might', 'genius']
# ['baby', 'make']
# ['ibenncocky', 'nooooyou', 'thingso', 'mean', 'special']
# ['joliechose', 'welcome', 'crash']
# ['unburnt']
# ['wafflesandnacho', 'knew', 'coming', 'meant', 'star']
# ['emdietrich', 'going', 'caribbean', 'even', 'latency', 'hahaaha', 'always', 'miss', 'concert', 'cause', 'vacation']
# ['oday', 'bird', 'flew', 'window', 'died', 'poor', 'thang']
# ['swollen', 'streaming', 'throat', 'swollen', 'voice', 'croaky', 'breathe', 'congested', 'headache']
# ['wanted', 'spend', 'hiding', 'behind', 'cloud']
# ['wish', 'ipod', 'wasnt', 'dead', 'need', 'musiiiiiiic']
# ['alffified', 'late', 'swap', 'plus', 'want', 'swap', 'lahh', 'still', 'cant', 'people', 'swap', '20th']
# ['rposslen', 'limit', 'story', 'tell', 'annoying']
# ['elpm', 'totally', 'tensehave', 'real', 'painmust', 'today', '400pm800pm', 'workjust', 'somehow', 'come', 'doctor']
# ['ooking', 'freeware', 'flight', 'sims', 'suggestion']
# ['celebrating', 'year', 'anniversary', 'hubby', 'today', 'best', 'year', 'life', 'thus']
# ['purelaura', 'good']
# ['late', 'know', 'discovered', 'moonpigcom', 'great', 'card']
# ['version', 'quotonequot', 'like', 'making', 'joke', 'ilhsfm']
# ['home', 'time', 'chicken', 'cutlet', 'house', 'special', 'leftover', 'hehe', 'mexichi', 'food', 'place', 'racial']
# ['cold', 'night', 'class', 'start', '16th', 'miss', 'friend', 'need', 'cash', 'allowance']
# ['soccergameball', 'breathe', 'soccer', 'live', 'socceruntil', 'hurt', 'knee', 'badly', 'waspass', 'link', 'around']
# ['queenbxoxo', 'heeeey', 'laughing', 'loud', 'fine', 'alright', 'urgh', 'feel', 'sick']
# ['timsbro2000', 'yikes', 'glad', 'hear', 'hope', 'work']
# ['solemateschi', 'really', 'spam', 'reducer', 'catch', 'mine', 'probably', 'traffic']
# ['jessicaveronica', 'actually', 'calamari', 'dinner', 'whats', 'place', 'check']
# ['istening', 'lvatt', 'soccer', 'early', 'tomorrow']
# ['dsanford', 'counter', 'morning', 'thing', 'lookin']
# ['raving', 'bulgogi', 'none', 'found', 'near', 'side', 'living', 'small', 'town']
# ['excited', 'start', 'beautiful', 'sunday', 'morning', 'migraine']
# ['atin', 'chocolate', 'cake', 'sheep', 'shirt', 'sweeettt', 'partay', 'tomorrow']
# ['oodness', 'fall', 'asleep', 'immediately', 'againi', 'need', 'coffee', 'today', 'keep', 'office']
# ['cherylnichols', 'thanks', 'followfriday', 'linkage', 'hope', 'great', 'weekend']
# ['enjoyed', 'strawberry', 'daiquiri', 'snocone', 'little', 'brother', 'opened', 'present']
# ['robinbrown78', 'mean', 'celeb', 'followed', 'thinking', 'related', 'gordon', 'silly']
# ['hope', 'dont', 'weird', 'brain', 'problem', 'disease', 'think', 'fine', 'though', 'nurse', 'doesnt', 'sound', 'worried']
# ['aching', 'cessna154s', 'video', 'youtube', 'going', 'facebook', 'looking', 'grade', 'ther', 'good', 'laughing', 'loud', 'europen', 'turkiey']
# ['xxcatx04xx', 'know', 'wait', 'hero', 'panel']
# ['phdinparenting', 'sound', 'good']
# ['heard', 'joan', 'river', 'celebrity', 'apprentice', 'oprah', 'think', 'someone', 'else', 'want', 'world']
# ['photo', 'work']
# ['hope', 'could', 'tattoo', 'soon', 'really', 'wish', 'tattoo', 'seems', 'like', 'parent', 'disagree']
# ['radha', 'always', 'welcome', 'sweety']
# ['tomfeltoni', 'fifth', 'filmtalked', 'wellsome', 'girl', 'saidyou', 'look', 'really', 'cute', 'pink', 'nectieyou', 'blushed', 'laughing', 'loud']
# ['trentreznor', 'happy', 'birthday']
# ['appiness']
# ['avoloch', 'alone']
# ['lease', 'give', 'strenght', 'shit', 'monday']
# ['ttptwitpiccom6bqhb', 'quite', 'fryup', 'still', 'work']
# ['feeling', 'good', 'today', 'cologne', 'hope', 'good', 'manchester', 'going', 'twitter', 'show']
# ['ttptwitpiccom5cruk', 'screamed', 'name', 'bathroom', 'opened', 'door', 'came', 'facebubbles']
# ['muggle2160', 'much', 'fanatic', 'used', 'watch', 'wimbledon', 'bjorn', 'borg', 'playing']
# ['curlin', 'hairor', 'tryn']
# ['sarahmarina']
# ['about', 'feed', 'doggy', 'walk', 'doggy', 'part', 'love', 'play', 'puppy']
# ['evising', 'test', 'tomo', 'sheesh', 'last', 'week', 'school', 'flipin', 'test']
# ['atching', 'crib', 'ryan', 'shecklers', 'house']
# ['life', 'people', 'thee']
# ['looking', 'movie', 'award', '2009', 'video', 'youtube']
# ['take', 'plain', 'white', 'tsgood', 'song']
# ['eutony', 'dear', 'trouble']
# ['ploading', 'schoolmate', 'photo', 'facebook', 'picture', 'blur', 'took', 'long', 'time', 'upload', 'connection', 'really']
# ['sleep', 'time', 'getting']
# ['mileycyrus', 'dont', 'worry', 'mile']
# ['chelleis', 'whoa', 'great', 'went', 'heaven', 'second', 'know', 'shhh', 'laughing', 'loud', 'sorry']
# ['getting', 'ready', 'history', 'regent', '1130']
# ['emilyawilliams', 'suck', 'sorry']
# ['souljaboytellem', 'lord', 'mercy', 'technology', 'much', 'tattos', 'dieu', 'ï¿½ï¿½', 'dï¿½', 'faire']
# ['phtwit', 'wake']
# ['starlighthair', 'hope', 'hayfeverweak']
# ['blah', 'jeff', 'waist', 'measurement', 'make']
# ['highclassdime', 'stuck', 'going', 'wedding', 'come', 'sure', 'info']
# ['chipperbebe', 'news', 'still', 'hold', 'gather']
# ['ollow', 'please', 'dday', 'jayz', 'robotpickuplines', 'death', 'autotune', 'tetri', 'goodnight', 'hangover', 'conan', 'jessicaveronica', 'palm']
# ['abysitttinggg', 'puppy', 'sick', 'least', 'think', 'long']
# ['washing', 'hand', 'twittering', 'timeman', 'skill']
# ['really', 'wana', 'arthe', 'said', 'lovebut', 'know', 'successful', 'major', 'confused']
# ['cagedangel', 'babe', 'involved', 'another', 'wish', 'last', 'minute', 'change', 'worry', 'within', 'month']
# ['bundle2baby', 'indeed']
# ['finally', 'finished', 'exam', 'yaaaay', 'actual', 'year', 'tomorrow', 'though']
# ['itouchedmytouch', 'lost', 'everything', 'forum', 'blog', 'iphoneus', 'really']
# ['alc4', 'hate', 'admit', 'right', 'laughing', 'loud', 'good', 'night']
# ['itsdice', 'done', 'london']
# ['envy', 'ally', 'fuck', 'ally', 'facebook', 'album', 'make', 'damn', 'depressed']
# ['eant', 'stop', 'redbox', 'coming', 'home', 'forgot', 'anything', 'good', 'tonight']
# ['jrkilla18', 'best', 'friend', 'need', 'talk', 'witt', 'chuu', 'stuff']
# ['pattinsonrobt', 'dont', 'know', 'either']
# ['estfriends', 'house', 'morning', 'shake', 'head', 'night', 'question', 'twitter', 'much']
# ['quotswept', 'away', 'sweetquot']
# ['thebeachgirl', 'haha', 'teasin']
# ['430am', 'answering', 'emailswish', 'lakers', 'parade']
# ['hotographerï¿½s', 'site', 'hishers', 'logo', 'reminds', 'avatar', 'cool', 'photo', 'tough']
# ['night', 'pretty', 'tired', 'watching', 'hockey', 'highlight', 'cause', 'miss', 'flyer']
# ['catching', 'beachexcept', 'left']
# ['going', 'first', 'ever', 'sexpo', 'could', 'interesting']
# ['going', 'shower']
# ['broke', 'boyfriend']
# ['trickyshirls', 'thanks', 'true', 'meeting', 'soul', 'mate', 'wonderful', 'never', 'thought', 'would', 'lifetime']
# ['parentsonly', 'week', 'house', 'hanging', 'bryan', 'later', 'making', 'dinner']
# ['ttptwitpiccom4h1k9', 'heyyy', 'going', 'nanas', 'soon', 'weather', 'sunny']
# ['sleep']
# ['girl', 'life', 'magazine', 'blog', 'check', 'brookieborg', 'moderated', 'written', 'former', 'blogger', 'good', 'luck', 'comment', 'back', 'lover']
# ['wack', 'headache']
# ['oves']
# ['digisal', 'mean', 'tired', 'hungry']
# ['ttptwitpiccom6eifl', 'fridgefreezerwars', 'stock', 'going', 'fast', 'trumped', 'fridge']
# ['need', 'guess', 'wait', 'morning', 'iphone', 'update']
# ['kathrynmurphy16', 'find', 'exciting', 'exam', 'know']
# ['hour', 'dead', 'work']
# ['think', 'whennu', 'found', 'already', 'year', 'never', 'back', 'went', 'grade']
# ['tã´i', 'cã²n', 'mã´n', 'xong', 'cháº¿t', 'cã¡i', 'mã´n', 'vä\x83n', 'báº£n', 'læ°u', 'tã\xadnh', 'hæ°á', 'ngæ°á', 'nghiá', 'vä\x83n', 'thæ°']
# ['albertinho', 'uugh', 'horrible']
# ['thing', 'wish', 'really', 'tired', 'going', 'warped']
# ['could', 'walk', 'hopefully', 'catch', 'later']
# ['fsteven', 'laughing', 'loud', 'voting', 'theatre', 'archies', 'haha']
# ['noahthered', 'youll', 'fine', 'sorry', 'really', 'really', 'wanted']
# ['stephaniemcg', 'mateee', 'shift', 'today', 'calling']
# ['abbafan69', 'always', 'nice', 'home', 'team', 'ahead']
# ['whocangetit', 'drake', 'tooo', 'sexy']
# ['lain', 'night', 'fishing']
# ['irst', 'exam', 'wish', 'luck']
# ['sick', 'rain']
# ['reason', 'wedding', 'wedding', 'party', 'meet', 'cute', 'single', 'open', 'none', 'applied', 'last', 'night']
# ['mghtydx', 'dude', 'going', 'lakers', 'game']
# ['writing', 'time', 'constraint', 'sekrit', 'project', 'started', '052609', 'deets', 'later']
# ['aucourantamour', 'nothing', 'sick']
# ['download', 'adobe', 'photoshop']
# ['crewed', 'fifa', 'password']
# ['hang']
# ['behtee', 'nuthin', 'micky', 'breakfast', 'havnt', 'hungry', 'since', 'inspired', 'mexican', 'want', 'taco']
# ['tracysparkles', 'early', 'later', 'office']
# ['werewolfseth', 'hope', 'weather', 'nice', 'cloudy', 'look', 'like', 'rain', 'wish', 'ocean']
# ['head', 'killing']
# ['minkus', 'feeling', 'hella', 'anxious', 'ticket']
# ['karenqgil', 'tweeting', 'fine']
# ['oodmorning', 'everyone']
# ['stephruiz28', 'kolache', 'mustard']
# ['hear', 'life', 'work', 'grazebox', 'come', 'punished', 'stealing']
# ['inner', 'finish', 'mage', 'profile', 'think']
# ['dgoodfellas', 'think', 'back', 'road']
# ['njoying', 'last', 'vacationback', 'work', 'monday']
# ['sarahboone', 'extra', 'hour', 'probably', 'price', 'though']
# ['rbearclaw', 'beverly', 'hill', 'thursday', 'waiting', 'jess', 'think', 'ended', 'walking', 'like', 'mile']
# ['allyheartsbb', 'hate', 'scary', 'movie', 'parent', 'tell', 'comfort', 'sleep']
# ['kderentz', 'said', 'could', 'take', 'till', 'least', 'maybe', 'later', 'didnt', 'work', 'tomorrow', 'guess']
# ['ravenousreadr', 'girl']
# ['officially', 'scariest', 'basement', 'ever', 'definitely', 'monsterszombies', 'living']
# ['tommcfly', 'read', 'online', 'article', 'mentionedmeh', 'happy', 'stuck', 'guysjust']
# ['today']
# ['kaufield', 'kept', 'jesse', 'james', 'instead', 'joan', 'river']
# ['aris', 'perfect']
# ['yoimajunkie', 'good']
# ['taralalaa', 'missing', 'tara', 'alberto']
# ['vegastweeter37', 'thanks', 'following']
# ['updating', 'thing', 'every', 'minute', 'follow', 'friend', 'follow', 'follow']
# ['love', 'sister', 'wordsshe', 'hate', 'hearing']
# ['mashtontaylor', 'kinda', 'girl', 'rubbing']
# ['work', 'usualmy', 'back', 'pretty', 'soredarn', 'idiot', 'drive']

# %% [markdown]
# Let's work with a smaller subset of words just to save up some time. Find the 1500 most occuring words in tweet data.

# %%
nr_of_words_to_use = 1500
popular_words = sorted(word_counter.items(), key=lambda x: x[1]['Pos'] + x[1]['Neg'], reverse=True)
popular_words = [x[0] for x in popular_words[:nr_of_words_to_use]]

# %% [markdown]
# Now lets compute P(w|pos), P(w|neg) for the popular words

# %%
P_w_given_pos = {}
P_w_given_neg = {}

N_pos = sum(final_train_labels == "Pos")
N_neg = sum(final_train_labels == "Neg")
for word in popular_words:
    pos_count = word_counter[word]['Pos']
    neg_count = word_counter[word]['Neg']
    
    P_w_given_pos[word] = (pos_count + 1) / (N_pos + len(popular_words))
    P_w_given_neg[word] = (neg_count + 1) / (N_neg + len(popular_words))

# %%
classifier = {
    'basis'  : popular_words,
    'P(pos)'   : P_pos,
    'P(neg)'   : P_neg,
    'P(w|pos)' : P_w_given_pos,
    'P(w|neg)' : P_w_given_neg
    }

# %% [markdown]
# #### Train and predict

# %% [markdown]
# Write a tweet_classifier function that takes your trained classifier and a tweet and returns wether it's about Positive or Negative using the popular words selected. Note that if there are words in the basis words in our classifier that are not in the tweet we have the opposite probabilities i.e P(w_1 occurs )* P(w_2 does not occur) * .... if w_1 occurs and w_2 does not occur. The function should return wether the tweet is Positive or Negative. i.e 'Pos' or 'Neg'.

# %%
def tweet_classifier(tweet, classifier_dict):
    tweet_words = (tweet.lower()).split()
    prob_pos = classifier_dict["P(pos)"]
    prob_neg = classifier_dict["P(neg)"]
    
    for word in classifier_dict["basis"]:
        if word in tweet_words:
            prob_pos *= classifier_dict["P(w|pos)"][word]
            prob_neg *= classifier_dict["P(w|neg)"][word]
        else:
            prob_pos *= (1 - classifier_dict["P(w|pos)"][word])
            prob_neg *= (1 - classifier_dict["P(w|neg)"][word])
    
    if prob_pos > prob_neg:
        return "Pos"
    else:
        return "Neg"
# ... Code for classifying tweets using the naive bayes classifier

# %%
def test_classifier(classifier, test_tweets, test_labels):
    total = len(test_tweets)
    correct = 0
    for (tweet,label) in zip(test_tweets, test_labels):
        predicted = tweet_classifier(tweet,classifier)
        if predicted == label:
            correct = correct + 1
    return(correct/total)

# %%
new_test_labels = test_labels.replace(0, "Neg", regex=True)
final_test_labels = new_test_labels.replace(1, "Pos", regex=True)

# %%
acc = test_classifier(classifier, test_tweets, final_test_labels)
print(f"Accuracy: {acc:.4f}")
# Out:
# Accuracy: 0.5000

# %% [markdown]
# #### Optional work
#
# In basic sentiment analysis classifications we have 3 classes "Positive", "Negative" and "Neutral". Although because it is challenging to create the "Neutral" class. Try to improve the accuracy by filtering the dataset from the perspective of removing words that indicate neutrality.
